# %%
# !pip install git+https://github.com/Ashhad785/synthcity.git

# %%
# !pip uninstall -y torchaudio torchdata
# !pip install pycox
from pycox import datasets
from synthcity.metrics import Metrics
from synthcity.plugins.core.dataloader import SurvivalAnalysisDataLoader
import numpy as np
import pandas as pd
import os
import shutil
from timeit import default_timer as timer
from synthcity.plugins import Plugins

# %%
plugin_name="ctgan"

# %% [markdown]
# # Functions

# %%
from scipy.stats import mannwhitneyu, chi2_contingency,wilcoxon
import matplotlib.pyplot as plt

def identify_variable_types(df):
    continuous_columns = []
    discrete_columns = []

    for col in df.columns:
        unique_vals = df[col].unique()
        num_unique = len(unique_vals)
        if num_unique > 20:  # Threshold for considering a column as continuous
            continuous_columns.append(col)
        else:
            discrete_columns.append(col)

    return continuous_columns, discrete_columns

def compare_distributions(real_df, synthetic_df, alpha=0.05):
    real_df = real_df.drop(['duration', 'event'], axis=1)
    real_continuous, real_discrete = identify_variable_types(real_df)
    p_values_continuous = {}
    p_values_discrete = {}

    synthetic_df = synthetic_df.drop(['duration', 'event'], axis=1)
    synthetic_continuous, synthetic_discrete = identify_variable_types(synthetic_df)

    synthetic_continuous = [col for col in synthetic_continuous if col not in ["event", "duration"]]
    synthetic_discrete = [col for col in synthetic_discrete if col not in ["event", "duration"]]

    # Wilcoxon rank-sum test for continuous variables
    for col in real_continuous:
        if col in synthetic_continuous:
            _, p_value = mannwhitneyu(real_df[col], synthetic_df[col])
            p_values_continuous[col] = p_value

    # Chi-square test for discrete variables
    for col in real_discrete:
        if col in synthetic_discrete:
            contingency_table = pd.crosstab(real_df[col], synthetic_df[col])
            _, p, _, _ = chi2_contingency(contingency_table)
            p_values_discrete[col] = p

    # Plot p-values
    # plt.figure(figsize=(10, 6))

    # continuous_p_values = {col: p_values_continuous[col] for col in real_continuous}
    # discrete_p_values = {col: p_values_discrete[col] for col in real_discrete}

    # plt.plot(list(continuous_p_values.keys()), list(continuous_p_values.values()), label='Continuous', marker='o')
    # plt.plot(list(discrete_p_values.keys()), list(discrete_p_values.values()), label='Discrete', marker='o', linestyle='dashed')

    # # Plot alpha line
    # plt.axhline(y=alpha, color='red', linestyle='--', label=f'alpha = {alpha}')

    # plt.xlabel('Column Name')
    # plt.ylabel('p-value')
    # plt.title('Comparison of p-values for Real and Synthetic Data')
    # plt.xticks(rotation=45)
    # plt.legend()
    # plt.grid(True)
    # plt.tight_layout()
    # plt.show()

    return p_values_continuous, p_values_discrete

# %% [markdown]
# # FLCHAIN

# %%
dataset="flchain"

metrics_list = []
fit_times = []
generate_times = []
p_values_list = []

for i in range(5):
    df = pd.read_csv('/content/drive/MyDrive/Datasets/flchain_final.csv')
    df = df.drop('Unnamed: 0', axis=1)
    df = df[df['duration'] != 0]

    syn_model = Plugins().get(plugin_name)
    X=df
    # Measure the execution time of the fit function
    start = timer()
    syn_model.fit(X)
    fit_time = timer() - start
    fit_times.append(fit_time)

    random_state = i + 1
    np.random.seed(random_state)

    # Measure the execution time of the generate function
    start = timer()
    X_gen = syn_model.generate(count=len(df)).dataframe()
    generate_time = timer() - start
    generate_times.append(generate_time)

    # Save X_gen as a CSV file
    X_gen.to_csv(f"/content/drive/MyDrive/Nips/{dataset}_{plugin_name}_nocond_iteration_{i+1}.csv", index=False)

    loader1 = SurvivalAnalysisDataLoader(df, target_column="event", time_to_event_column="duration")
    loader2 = SurvivalAnalysisDataLoader(X_gen, target_column="event", time_to_event_column="duration")

    met_df = Metrics.evaluate(X_gt=loader1, X_syn=loader2, task_type='survival_analysis', metrics={
        'stats': ['jensenshannon_dist', 'chi_squared_test', 'feature_corr', 'inv_kl_divergence', 'ks_test',
                 'max_mean_discrepancy', 'wasserstein_dist', 'prdc', 'alpha_precision', 'survival_km_distance'],
        'performance': ['linear_model', 'mlp', 'xgb', 'feat_rank_distance']
    }, use_cache=False, random_state=random_state)

    met_df = met_df.iloc[:, 0]
    metrics_list.append(met_df)

    # Calculate p-values
    p_values_continuous, p_values_discrete = compare_distributions(df, X_gen)
    continuous_column_names = list(p_values_continuous.keys())
    discrete_column_names = list(p_values_discrete.keys())

    p_val = np.concatenate([list(p_values_continuous.values()), list(p_values_discrete.values())])
    p_values_list.append(p_val)

    workspace_dir = os.path.join(os.getcwd(), 'workspace')
    if os.path.exists(workspace_dir):
        shutil.rmtree(workspace_dir)

result_df = pd.concat(metrics_list, axis=1)

# Calculate the row-wise mean and standard deviation of the metrics
result_df['Mean'] = result_df.mean(axis=1)
result_df['Std'] = result_df.std(axis=1)
result_df['Std'] = result_df['Std'].round(4)

# Create DataFrame for p-values
p_values_df = pd.DataFrame(p_values_list, columns=continuous_column_names + discrete_column_names)

# Save result_df and p_values_df as CSV files
result_df.to_csv(f"/content/drive/MyDrive/Nips/{dataset}_{plugin_name}_nocond_result_df.csv")
p_values_df.to_csv(f"/content/drive/MyDrive/Nips/{dataset}_{plugin_name}_nocond_p_values_df.csv")

avg_fit_time = np.mean(fit_times)
avg_generate_time = np.mean(generate_times)
std_fit_time = np.std(fit_times)
std_generate_time = np.std(generate_times)

print(f"\nAverage Fit Time: {avg_fit_time:.4f} seconds, Standard Deviation: {std_fit_time:.4f} seconds")
print(f"Average Generate Time: {avg_generate_time:.4f} seconds, Standard Deviation: {std_generate_time:.4f} seconds")
# Out:
# [2024-04-19T22:38:21.591519+0000][1377][CRITICAL] module disabled: /usr/local/lib/python3.10/dist-packages/synthcity/plugins/generic/plugin_goggle.py
#  25%|██▍       | 499/2000 [08:22<25:11,  1.01s/it]
# [KeOps] Generating code for Max_SumShiftExpWeight_Reduction reduction (with parameters 0) of formula [c-1/2*(d*Sum((a-b)**2)),1] with a=Var(0,11,0), b=Var(1,11,1), c=Var(2,1,1), d=Var(3,1,2) ... OK
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [2024-04-19T22:52:52.570611+0000][1377][CRITICAL] module disabled: /usr/local/lib/python3.10/dist-packages/synthcity/plugins/generic/plugin_goggle.py
#  25%|██▍       | 499/2000 [08:26<25:22,  1.01s/it]
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [2024-04-19T23:07:12.692475+0000][1377][CRITICAL] module disabled: /usr/local/lib/python3.10/dist-packages/synthcity/plugins/generic/plugin_goggle.py
#  25%|██▍       | 499/2000 [08:27<25:26,  1.02s/it]
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [2024-04-19T23:21:53.888532+0000][1377][CRITICAL] module disabled: /usr/local/lib/python3.10/dist-packages/synthcity/plugins/generic/plugin_goggle.py
#  25%|██▍       | 499/2000 [08:26<25:24,  1.02s/it]
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [2024-04-19T23:36:32.468572+0000][1377][CRITICAL] module disabled: /usr/local/lib/python3.10/dist-packages/synthcity/plugins/generic/plugin_goggle.py
#  25%|██▍       | 499/2000 [08:27<25:27,  1.02s/it]
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
#
# Average Fit Time: 513.0025 seconds, Standard Deviation: 1.9139 seconds
# Average Generate Time: 0.1245 seconds, Standard Deviation: 0.0117 seconds

# %%
result_df
# Out:
#                                                    min       min       min  \
# stats.jensenshannon_dist.marginal             0.005824  0.005791  0.005786
# stats.chi_squared_test.marginal               0.624263  0.624142  0.624317
# stats.inv_kl_divergence.marginal              0.937778  0.937862  0.938030
# stats.ks_test.marginal                        0.866449  0.866668  0.866680
# stats.max_mean_discrepancy.joint              0.000262  0.000261  0.000261
# stats.wasserstein_dist.joint                  0.021938  0.021545  0.021755
# stats.prdc.precision                          0.964935  0.966586  0.965570
# stats.prdc.recall                             0.986279  0.985516  0.985771
# stats.prdc.density                            0.868276  0.868378  0.872824
# stats.prdc.coverage                           0.809046  0.812603  0.806505
# stats.survival_km_distance.optimism          -0.035237 -0.037047 -0.037313
# stats.survival_km_distance.abs_optimism       0.035237  0.037054  0.037320
# stats.survival_km_distance.sightedness        0.017833  0.017833  0.020134
# performance.linear_model.gt.c_index           0.864923  0.864923  0.864923
# performance.linear_model.gt.brier_score       0.086823  0.086823  0.086823
# performance.linear_model.syn_id.c_index       0.865697  0.865768  0.866189
# performance.linear_model.syn_id.brier_score   0.085825  0.085950  0.085938
# performance.linear_model.syn_ood.c_index      0.876674  0.876979  0.877204
# performance.linear_model.syn_ood.brier_score  0.084481  0.084641  0.084715
# performance.mlp.gt.c_index                    0.798863  0.798863  0.798863
# performance.mlp.gt.brier_score                0.094956  0.094956  0.094956
# performance.mlp.syn_id.c_index                0.839302  0.791981  0.848711
# performance.mlp.syn_id.brier_score            0.088524  0.092940  0.085026
# performance.mlp.syn_ood.c_index               0.747752  0.752824  0.801497
# performance.mlp.syn_ood.brier_score           0.093937  0.094007  0.093621
# performance.xgb.gt.c_index                    0.869622  0.870668  0.871006
# performance.xgb.gt.brier_score                0.094515  0.093983  0.093696
# performance.xgb.syn_id.c_index                0.866045  0.866067  0.864718
# performance.xgb.syn_id.brier_score            0.089415  0.089187  0.089405
# performance.xgb.syn_ood.c_index               0.878996  0.876855  0.878135
# performance.xgb.syn_ood.brier_score           0.087274  0.087098  0.086929
#
#                                                    min       min      Mean  \
# stats.jensenshannon_dist.marginal             0.005847  0.005831  0.005816
# stats.chi_squared_test.marginal               0.623993  0.623983  0.624140
# stats.inv_kl_divergence.marginal              0.937964  0.937947  0.937916
# stats.ks_test.marginal                        0.866322  0.866726  0.866569
# stats.max_mean_discrepancy.joint              0.000261  0.000261  0.000261
# stats.wasserstein_dist.joint                  0.021553  0.021347  0.021628
# stats.prdc.precision                          0.966078  0.966713  0.965976
# stats.prdc.recall                             0.986787  0.985644  0.985999
# stats.prdc.density                            0.875086  0.867056  0.870324
# stats.prdc.coverage                           0.812603  0.813874  0.810926
# stats.survival_km_distance.optimism          -0.040265 -0.038335 -0.037640
# stats.survival_km_distance.abs_optimism       0.040271  0.038341  0.037645
# stats.survival_km_distance.sightedness        0.014765  0.017450  0.017603
# performance.linear_model.gt.c_index           0.864923  0.864923  0.864923
# performance.linear_model.gt.brier_score       0.086823  0.086823  0.086823
# performance.linear_model.syn_id.c_index       0.865677  0.865611  0.865788
# performance.linear_model.syn_id.brier_score   0.085982  0.085885  0.085916
# performance.linear_model.syn_ood.c_index      0.876426  0.876677  0.876792
# performance.linear_model.syn_ood.brier_score  0.084720  0.084490  0.084609
# performance.mlp.gt.c_index                    0.798863  0.798863  0.798863
# performance.mlp.gt.brier_score                0.094956  0.094956  0.094956
# performance.mlp.syn_id.c_index                0.840553  0.837473  0.831604
# performance.mlp.syn_id.brier_score            0.086228  0.091397  0.088823
# performance.mlp.syn_ood.c_index               0.847243  0.856552  0.801173
# performance.mlp.syn_ood.brier_score           0.082952  0.085528  0.090009
# performance.xgb.gt.c_index                    0.870488  0.870229  0.870403
# performance.xgb.gt.brier_score                0.094100  0.094281  0.094115
# performance.xgb.syn_id.c_index                0.866420  0.865964  0.865843
# performance.xgb.syn_id.brier_score            0.088675  0.088993  0.089135
# performance.xgb.syn_ood.c_index               0.879465  0.878560  0.878402
# performance.xgb.syn_ood.brier_score           0.086491  0.086719  0.086902
#
#                                                  Std
# stats.jensenshannon_dist.marginal             0.0000
# stats.chi_squared_test.marginal               0.0001
# stats.inv_kl_divergence.marginal              0.0001
# stats.ks_test.marginal                        0.0002
# stats.max_mean_discrepancy.joint              0.0000
# stats.wasserstein_dist.joint                  0.0002
# stats.prdc.precision                          0.0007
# stats.prdc.recall                             0.0005
# stats.prdc.density                            0.0031
# stats.prdc.coverage                           0.0027
# stats.survival_km_distance.optimism           0.0016
# stats.survival_km_distance.abs_optimism       0.0017
# stats.survival_km_distance.sightedness        0.0017
# performance.linear_model.gt.c_index           0.0000
# performance.linear_model.gt.brier_score       0.0000
# performance.linear_model.syn_id.c_index       0.0002
# performance.linear_model.syn_id.brier_score   0.0001
# performance.linear_model.syn_ood.c_index      0.0003
# performance.linear_model.syn_ood.brier_score  0.0001
# performance.mlp.gt.c_index                    0.0000
# performance.mlp.gt.brier_score                0.0000
# performance.mlp.syn_id.c_index                0.0202
# performance.mlp.syn_id.brier_score            0.0030
# performance.mlp.syn_ood.c_index               0.0456
# performance.mlp.syn_ood.brier_score           0.0048
# performance.xgb.gt.c_index                    0.0005
# performance.xgb.gt.brier_score                0.0003
# performance.xgb.syn_id.c_index                0.0006
# performance.xgb.syn_id.brier_score            0.0003
# performance.xgb.syn_ood.c_index               0.0009
# performance.xgb.syn_ood.brier_score           0.0003

# %%
p_values_df
# Out:
#             age         kappa        lambda    creatinine       sex  \
# 0  3.685625e-77  7.149978e-13  2.401125e-49  1.253561e-21  0.751146
# 1  3.785055e-78  1.838366e-13  4.857980e-51  9.947070e-21  0.850218
# 2  1.446438e-76  6.281723e-13  4.545437e-49  1.153858e-20  0.978087
# 3  7.823914e-77  9.208031e-13  2.196384e-50  3.394050e-21  0.881069
# 4  5.239544e-76  4.058707e-13  5.393889e-49  1.012756e-19  0.920359
#
#    sample.yr   flc.grp      mgus   chapter
# 0   0.713233  0.392621  0.447718  0.521891
# 1   0.549042  0.285245  0.974322  0.434317
# 2   0.736810  0.276600  0.420234  0.131515
# 3   0.820678  0.566046  1.000000  0.326209
# 4   0.704702  0.431346  0.392921  0.100039

# %% [markdown]
# # AIDS

# %%
dataset="aids"

metrics_list = []
fit_times = []
generate_times = []
p_values_list = []

for i in range(5):
    df = pd.read_csv('/content/drive/MyDrive/Datasets/aids.csv')
    df = df.drop('Unnamed: 0', axis=1)
    df = df[df['duration'] != 0]

    syn_model = Plugins().get(plugin_name)
    X=df
    # Measure the execution time of the fit function
    start = timer()
    syn_model.fit(X)
    fit_time = timer() - start
    fit_times.append(fit_time)

    random_state = i + 1
    np.random.seed(random_state)

    # Measure the execution time of the generate function
    start = timer()
    X_gen = syn_model.generate(count=len(df)).dataframe()
    generate_time = timer() - start
    generate_times.append(generate_time)

    # Save X_gen as a CSV file
    X_gen.to_csv(f"/content/drive/MyDrive/Nips/{dataset}_{plugin_name}_nocond_iteration_{i+1}.csv", index=False)

    loader1 = SurvivalAnalysisDataLoader(df, target_column="event", time_to_event_column="duration")
    loader2 = SurvivalAnalysisDataLoader(X_gen, target_column="event", time_to_event_column="duration")

    met_df = Metrics.evaluate(X_gt=loader1, X_syn=loader2, task_type='survival_analysis', metrics={
        'stats': ['jensenshannon_dist', 'chi_squared_test', 'feature_corr', 'inv_kl_divergence', 'ks_test',
                 'max_mean_discrepancy', 'wasserstein_dist', 'prdc', 'alpha_precision', 'survival_km_distance'],
        'performance': ['linear_model', 'mlp', 'xgb', 'feat_rank_distance']
    }, use_cache=False, random_state=random_state)

    met_df = met_df.iloc[:, 0]
    metrics_list.append(met_df)

    # Calculate p-values
    p_values_continuous, p_values_discrete = compare_distributions(df, X_gen)
    continuous_column_names = list(p_values_continuous.keys())
    discrete_column_names = list(p_values_discrete.keys())

    p_val = np.concatenate([list(p_values_continuous.values()), list(p_values_discrete.values())])
    p_values_list.append(p_val)

    workspace_dir = os.path.join(os.getcwd(), 'workspace')
    if os.path.exists(workspace_dir):
        shutil.rmtree(workspace_dir)

result_df = pd.concat(metrics_list, axis=1)

# Calculate the row-wise mean and standard deviation of the metrics
result_df['Mean'] = result_df.mean(axis=1)
result_df['Std'] = result_df.std(axis=1)
result_df['Std'] = result_df['Std'].round(4)

# Create DataFrame for p-values
p_values_df = pd.DataFrame(p_values_list, columns=continuous_column_names + discrete_column_names)

# Save result_df and p_values_df as CSV files
result_df.to_csv(f"/content/drive/MyDrive/Nips/{dataset}_{plugin_name}_nocond_result_df.csv")
p_values_df.to_csv(f"/content/drive/MyDrive/Nips/{dataset}_{plugin_name}_nocond_p_values_df.csv")

avg_fit_time = np.mean(fit_times)
avg_generate_time = np.mean(generate_times)
std_fit_time = np.std(fit_times)
std_generate_time = np.std(generate_times)

print(f"\nAverage Fit Time: {avg_fit_time:.4f} seconds, Standard Deviation: {std_fit_time:.4f} seconds")
print(f"Average Generate Time: {avg_generate_time:.4f} seconds, Standard Deviation: {std_generate_time:.4f} seconds")
# Out:
# [2024-04-19T23:51:07.243674+0000][1377][CRITICAL] module disabled: /usr/local/lib/python3.10/dist-packages/synthcity/plugins/generic/plugin_goggle.py
#  72%|███████▏  | 1449/2000 [04:38<01:46,  5.20it/s]
# [2024-04-19T23:56:48.914372+0000][1377][CRITICAL] module disabled: /usr/local/lib/python3.10/dist-packages/synthcity/plugins/generic/plugin_goggle.py
#  72%|███████▏  | 1449/2000 [04:39<01:46,  5.19it/s]
# [2024-04-20T00:02:31.503345+0000][1377][CRITICAL] module disabled: /usr/local/lib/python3.10/dist-packages/synthcity/plugins/generic/plugin_goggle.py
#  72%|███████▏  | 1449/2000 [04:38<01:46,  5.19it/s]
# [2024-04-20T00:08:13.099380+0000][1377][CRITICAL] module disabled: /usr/local/lib/python3.10/dist-packages/synthcity/plugins/generic/plugin_goggle.py
#  72%|███████▏  | 1449/2000 [04:39<01:46,  5.18it/s]
# [2024-04-20T00:13:54.293297+0000][1377][CRITICAL] module disabled: /usr/local/lib/python3.10/dist-packages/synthcity/plugins/generic/plugin_goggle.py
#  72%|███████▏  | 1449/2000 [04:39<01:46,  5.19it/s]
# Average Fit Time: 281.0611 seconds, Standard Deviation: 0.4652 seconds
# Average Generate Time: 0.0792 seconds, Standard Deviation: 0.0026 seconds

# %%
result_df
# Out:
#                                                    min       min       min  \
# stats.jensenshannon_dist.marginal             0.007846  0.008251  0.008159
# stats.chi_squared_test.marginal               0.833660  0.756574  0.756058
# stats.inv_kl_divergence.marginal              0.945473  0.942242  0.941453
# stats.ks_test.marginal                        0.940988  0.937847  0.938315
# stats.max_mean_discrepancy.joint              0.001738  0.001738  0.001738
# stats.wasserstein_dist.joint                  0.061490  0.063997  0.058614
# stats.prdc.precision                          0.994787  0.997394  0.997394
# stats.prdc.recall                             0.926151  0.920070  0.926151
# stats.prdc.density                            1.077150  1.091051  1.083232
# stats.prdc.coverage                           0.874023  0.893136  0.876629
# stats.survival_km_distance.optimism          -0.007832 -0.009059 -0.001944
# stats.survival_km_distance.abs_optimism       0.015453  0.016140  0.015189
# stats.survival_km_distance.sightedness        0.072793  0.071773  0.074752
# performance.linear_model.gt.c_index           0.760921  0.760921  0.760921
# performance.linear_model.gt.brier_score       0.062355  0.062355  0.062355
# performance.linear_model.syn_id.c_index       0.736590  0.734366  0.758552
# performance.linear_model.syn_id.brier_score   0.063179  0.060910  0.060433
# performance.linear_model.syn_ood.c_index      0.765535  0.796097  0.771236
# performance.linear_model.syn_ood.brier_score  0.065018  0.063527  0.064796
# performance.mlp.gt.c_index                    0.725780  0.725780  0.725780
# performance.mlp.gt.brier_score                0.071506  0.071506  0.071506
# performance.mlp.syn_id.c_index                0.648894  0.562289  0.736350
# performance.mlp.syn_id.brier_score            0.065450  0.067288  0.065364
# performance.mlp.syn_ood.c_index               0.620944  0.598667  0.611296
# performance.mlp.syn_ood.brier_score           0.071280  0.082620  0.066700
# performance.xgb.gt.c_index                    0.723639  0.727740  0.717010
# performance.xgb.gt.brier_score                0.064598  0.064634  0.064619
# performance.xgb.syn_id.c_index                0.743474  0.742994  0.735638
# performance.xgb.syn_id.brier_score            0.063678  0.063765  0.064292
# performance.xgb.syn_ood.c_index               0.713714  0.708265  0.697583
# performance.xgb.syn_ood.brier_score           0.062395  0.062376  0.062748
#
#                                                    min       min      Mean  \
# stats.jensenshannon_dist.marginal             0.007842  0.007889  0.007997
# stats.chi_squared_test.marginal               0.757799  0.834232  0.787665
# stats.inv_kl_divergence.marginal              0.939588  0.951929  0.944137
# stats.ks_test.marginal                        0.940720  0.941389  0.939852
# stats.max_mean_discrepancy.joint              0.001738  0.001738  0.001738
# stats.wasserstein_dist.joint                  0.063930  0.060067  0.061620
# stats.prdc.precision                          0.997394  0.993918  0.996177
# stats.prdc.recall                             0.906169  0.915725  0.918853
# stats.prdc.density                            1.088792  1.086533  1.085352
# stats.prdc.coverage                           0.868810  0.873154  0.877150
# stats.survival_km_distance.optimism          -0.003514 -0.006626 -0.005795
# stats.survival_km_distance.abs_optimism       0.015735  0.015362  0.015576
# stats.survival_km_distance.sightedness        0.071693  0.068204  0.071843
# performance.linear_model.gt.c_index           0.760921  0.760921  0.760921
# performance.linear_model.gt.brier_score       0.062355  0.062355  0.062355
# performance.linear_model.syn_id.c_index       0.757522  0.765827  0.750571
# performance.linear_model.syn_id.brier_score   0.062071  0.060243  0.061367
# performance.linear_model.syn_ood.c_index      0.793711  0.772305  0.779777
# performance.linear_model.syn_ood.brier_score  0.062503  0.065143  0.064197
# performance.mlp.gt.c_index                    0.725780  0.725780  0.725780
# performance.mlp.gt.brier_score                0.071506  0.071506  0.071506
# performance.mlp.syn_id.c_index                0.598157  0.624053  0.633949
# performance.mlp.syn_id.brier_score            0.067870  0.065240  0.066242
# performance.mlp.syn_ood.c_index               0.532126  0.594198  0.591446
# performance.mlp.syn_ood.brier_score           0.073313  0.067180  0.072219
# performance.xgb.gt.c_index                    0.717547  0.723610  0.721909
# performance.xgb.gt.brier_score                0.064591  0.064625  0.064614
# performance.xgb.syn_id.c_index                0.753119  0.745147  0.744074
# performance.xgb.syn_id.brier_score            0.064111  0.063916  0.063952
# performance.xgb.syn_ood.c_index               0.724894  0.699148  0.708721
# performance.xgb.syn_ood.brier_score           0.062533  0.062597  0.062530
#
#                                                  Std
# stats.jensenshannon_dist.marginal             0.0002
# stats.chi_squared_test.marginal               0.0378
# stats.inv_kl_divergence.marginal              0.0043
# stats.ks_test.marginal                        0.0015
# stats.max_mean_discrepancy.joint              0.0000
# stats.wasserstein_dist.joint                  0.0021
# stats.prdc.precision                          0.0015
# stats.prdc.recall                             0.0075
# stats.prdc.density                            0.0048
# stats.prdc.coverage                           0.0084
# stats.survival_km_distance.optimism           0.0027
# stats.survival_km_distance.abs_optimism       0.0003
# stats.survival_km_distance.sightedness        0.0021
# performance.linear_model.gt.c_index           0.0000
# performance.linear_model.gt.brier_score       0.0000
# performance.linear_model.syn_id.c_index       0.0127
# performance.linear_model.syn_id.brier_score   0.0011
# performance.linear_model.syn_ood.c_index      0.0126
# performance.linear_model.syn_ood.brier_score  0.0010
# performance.mlp.gt.c_index                    0.0000
# performance.mlp.gt.brier_score                0.0000
# performance.mlp.syn_id.c_index                0.0587
# performance.mlp.syn_id.brier_score            0.0011
# performance.mlp.syn_ood.c_index               0.0311
# performance.mlp.syn_ood.brier_score           0.0058
# performance.xgb.gt.c_index                    0.0041
# performance.xgb.gt.brier_score                0.0000
# performance.xgb.syn_id.c_index                0.0056
# performance.xgb.syn_id.brier_score            0.0002
# performance.xgb.syn_ood.c_index               0.0100
# performance.xgb.syn_ood.brier_score           0.0001

# %%
p_values_df
# Out:
#         age       cd4  priorzdv  hemophil    ivdrug    karnof    raceth  \
# 0  0.000025  0.009989  0.284490  0.582189  0.966148  0.355496  0.150918
# 1  0.000019  0.009262  0.288531  1.000000  0.685472  0.203800  0.312499
# 2  0.000006  0.027894  0.404605  0.582189  0.720066  0.477754  0.193536
# 3  0.000002  0.037497  0.228223  0.582189  0.655114  0.648449  0.243695
# 4  0.000016  0.022279  0.249290  0.137161  0.950359  0.560413  0.069481
#
#         sex    strat2        tx     txgrp
# 0  0.234461  0.173183  0.496377  0.928062
# 1  0.246964  0.123337  0.424347  0.931062
# 2  0.633631  0.178271  0.459915  0.859484
# 3  0.463991  0.149245  0.615116  0.814682
# 4  0.176643  0.241894  0.743613  0.948738

# %% [markdown]
# # Metabric

# %%
dataset="metabric"

metrics_list = []
fit_times = []
generate_times = []
p_values_list = []

for i in range(5):
    df = datasets.metabric.read_df()
    df = df[df['duration'] != 0]

    syn_model = Plugins().get(plugin_name)
    X=df
    # Measure the execution time of the fit function
    start = timer()
    syn_model.fit(X)
    fit_time = timer() - start
    fit_times.append(fit_time)

    random_state = i + 1
    np.random.seed(random_state)

    # Measure the execution time of the generate function
    start = timer()
    X_gen = syn_model.generate(count=len(df)).dataframe()
    generate_time = timer() - start
    generate_times.append(generate_time)

    # Save X_gen as a CSV file
    X_gen.to_csv(f"/content/drive/MyDrive/Nips/{dataset}_{plugin_name}_nocond_iteration_{i+1}.csv", index=False)

    loader1 = SurvivalAnalysisDataLoader(df, target_column="event", time_to_event_column="duration")
    loader2 = SurvivalAnalysisDataLoader(X_gen, target_column="event", time_to_event_column="duration")

    met_df = Metrics.evaluate(X_gt=loader1, X_syn=loader2, task_type='survival_analysis', metrics={
        'stats': ['jensenshannon_dist', 'chi_squared_test', 'feature_corr', 'inv_kl_divergence', 'ks_test',
                 'max_mean_discrepancy', 'wasserstein_dist', 'prdc', 'alpha_precision', 'survival_km_distance'],
        'performance': ['linear_model', 'mlp', 'xgb', 'feat_rank_distance']
    }, use_cache=False, random_state=random_state)

    met_df = met_df.iloc[:, 0]
    metrics_list.append(met_df)

    # Calculate p-values
    p_values_continuous, p_values_discrete = compare_distributions(df, X_gen)
    continuous_column_names = list(p_values_continuous.keys())
    discrete_column_names = list(p_values_discrete.keys())

    p_val = np.concatenate([list(p_values_continuous.values()), list(p_values_discrete.values())])
    p_values_list.append(p_val)

    workspace_dir = os.path.join(os.getcwd(), 'workspace')
    if os.path.exists(workspace_dir):
        shutil.rmtree(workspace_dir)

result_df = pd.concat(metrics_list, axis=1)

# Calculate the row-wise mean and standard deviation of the metrics
result_df['Mean'] = result_df.mean(axis=1)
result_df['Std'] = result_df.std(axis=1)
result_df['Std'] = result_df['Std'].round(4)

# Create DataFrame for p-values
p_values_df = pd.DataFrame(p_values_list, columns=continuous_column_names + discrete_column_names)

# Save result_df and p_values_df as CSV files
result_df.to_csv(f"/content/drive/MyDrive/Nips/{dataset}_{plugin_name}_nocond_result_df.csv")
p_values_df.to_csv(f"/content/drive/MyDrive/Nips/{dataset}_{plugin_name}_nocond_p_values_df.csv")

avg_fit_time = np.mean(fit_times)
avg_generate_time = np.mean(generate_times)
std_fit_time = np.std(fit_times)
std_generate_time = np.std(generate_times)

print(f"\nAverage Fit Time: {avg_fit_time:.4f} seconds, Standard Deviation: {std_fit_time:.4f} seconds")
print(f"Average Generate Time: {avg_generate_time:.4f} seconds, Standard Deviation: {std_generate_time:.4f} seconds")
# Out:
# Dataset 'metabric' not locally available. Downloading...
# [2024-04-20T00:19:36.780488+0000][1377][CRITICAL] module disabled: /usr/local/lib/python3.10/dist-packages/synthcity/plugins/generic/plugin_goggle.py
# Done
#  20%|█▉        | 399/2000 [01:48<07:16,  3.67it/s]
# [2024-04-20T00:23:10.577508+0000][1377][CRITICAL] module disabled: /usr/local/lib/python3.10/dist-packages/synthcity/plugins/generic/plugin_goggle.py
#  20%|█▉        | 399/2000 [01:50<07:22,  3.62it/s]
# [2024-04-20T00:26:47.789247+0000][1377][CRITICAL] module disabled: /usr/local/lib/python3.10/dist-packages/synthcity/plugins/generic/plugin_goggle.py
#  20%|█▉        | 399/2000 [01:49<07:21,  3.63it/s]
# [2024-04-20T00:30:22.709871+0000][1377][CRITICAL] module disabled: /usr/local/lib/python3.10/dist-packages/synthcity/plugins/generic/plugin_goggle.py
#  20%|█▉        | 399/2000 [01:49<07:19,  3.65it/s]
# [2024-04-20T00:33:58.293684+0000][1377][CRITICAL] module disabled: /usr/local/lib/python3.10/dist-packages/synthcity/plugins/generic/plugin_goggle.py
#  20%|█▉        | 399/2000 [01:50<07:23,  3.61it/s]
# Average Fit Time: 112.6770 seconds, Standard Deviation: 0.3831 seconds
# Average Generate Time: 0.0878 seconds, Standard Deviation: 0.0041 seconds

# %%
result_df
# Out:
#                                                    min       min       min  \
# stats.jensenshannon_dist.marginal             0.012045  0.012793  0.012374
# stats.chi_squared_test.marginal               0.624305  0.619957  0.622046
# stats.inv_kl_divergence.marginal              0.883081  0.881954  0.883066
# stats.ks_test.marginal                        0.891033  0.889552  0.888979
# stats.max_mean_discrepancy.joint              0.001063  0.001061  0.001065
# stats.wasserstein_dist.joint                  0.041228  0.041507  0.040145
# stats.prdc.precision                          0.976353  0.979506  0.978981
# stats.prdc.recall                             0.950604  0.930110  0.939569
# stats.prdc.density                            0.956595  0.966474  0.959643
# stats.prdc.coverage                           0.823962  0.815029  0.816080
# stats.survival_km_distance.optimism           0.022545  0.016126  0.019416
# stats.survival_km_distance.abs_optimism       0.029066  0.027634  0.028920
# stats.survival_km_distance.sightedness        0.055070  0.049810  0.053204
# performance.linear_model.gt.c_index           0.630465  0.630465  0.630465
# performance.linear_model.gt.brier_score       0.189282  0.189282  0.189282
# performance.linear_model.syn_id.c_index       0.620510  0.623250  0.625536
# performance.linear_model.syn_id.brier_score   0.200752  0.199662  0.199850
# performance.linear_model.syn_ood.c_index      0.624216  0.624821  0.628292
# performance.linear_model.syn_ood.brier_score  0.207638  0.207011  0.207313
# performance.mlp.gt.c_index                    0.541779  0.541779  0.541779
# performance.mlp.gt.brier_score                0.213681  0.213681  0.213681
# performance.mlp.syn_id.c_index                0.584506  0.579039  0.590303
# performance.mlp.syn_id.brier_score            0.210530  0.204760  0.211098
# performance.mlp.syn_ood.c_index               0.553899  0.587157  0.588134
# performance.mlp.syn_ood.brier_score           0.211100  0.213301  0.216342
# performance.xgb.gt.c_index                    0.636638  0.636959  0.636790
# performance.xgb.gt.brier_score                0.200157  0.200245  0.200107
# performance.xgb.syn_id.c_index                0.644164  0.650731  0.647468
# performance.xgb.syn_id.brier_score            0.197710  0.197279  0.197601
# performance.xgb.syn_ood.c_index               0.655735  0.656865  0.656114
# performance.xgb.syn_ood.brier_score           0.202098  0.202406  0.202693
#
#                                                    min       min      Mean  \
# stats.jensenshannon_dist.marginal             0.012314  0.012589  0.012423
# stats.chi_squared_test.marginal               0.531274  0.621494  0.603815
# stats.inv_kl_divergence.marginal              0.876600  0.880482  0.881036
# stats.ks_test.marginal                        0.890412  0.890508  0.890097
# stats.max_mean_discrepancy.joint              0.001063  0.001064  0.001063
# stats.wasserstein_dist.joint                  0.042583  0.040940  0.041281
# stats.prdc.precision                          0.976353  0.978981  0.978035
# stats.prdc.recall                             0.939044  0.951130  0.942091
# stats.prdc.density                            0.962165  0.966684  0.962312
# stats.prdc.coverage                           0.825013  0.807147  0.817446
# stats.survival_km_distance.optimism           0.015062  0.012462  0.017122
# stats.survival_km_distance.abs_optimism       0.027093  0.031533  0.028849
# stats.survival_km_distance.sightedness        0.055070  0.067585  0.056148
# performance.linear_model.gt.c_index           0.630465  0.630465  0.630465
# performance.linear_model.gt.brier_score       0.189282  0.189282  0.189282
# performance.linear_model.syn_id.c_index       0.624228  0.620254  0.622756
# performance.linear_model.syn_id.brier_score   0.199273  0.200617  0.200031
# performance.linear_model.syn_ood.c_index      0.629575  0.624656  0.626312
# performance.linear_model.syn_ood.brier_score  0.205608  0.208121  0.207138
# performance.mlp.gt.c_index                    0.541779  0.541779  0.541779
# performance.mlp.gt.brier_score                0.213681  0.213681  0.213681
# performance.mlp.syn_id.c_index                0.586302  0.552296  0.578489
# performance.mlp.syn_id.brier_score            0.211821  0.212423  0.210127
# performance.mlp.syn_ood.c_index               0.584908  0.588474  0.580515
# performance.mlp.syn_ood.brier_score           0.216406  0.217395  0.214909
# performance.xgb.gt.c_index                    0.635815  0.636592  0.636559
# performance.xgb.gt.brier_score                0.200242  0.200131  0.200176
# performance.xgb.syn_id.c_index                0.646090  0.647389  0.647169
# performance.xgb.syn_id.brier_score            0.198073  0.197484  0.197629
# performance.xgb.syn_ood.c_index               0.653972  0.656887  0.655915
# performance.xgb.syn_ood.brier_score           0.203431  0.202334  0.202592
#
#                                                  Std
# stats.jensenshannon_dist.marginal             0.0003
# stats.chi_squared_test.marginal               0.0363
# stats.inv_kl_divergence.marginal              0.0024
# stats.ks_test.marginal                        0.0007
# stats.max_mean_discrepancy.joint              0.0000
# stats.wasserstein_dist.joint                  0.0008
# stats.prdc.precision                          0.0014
# stats.prdc.recall                             0.0079
# stats.prdc.density                            0.0039
# stats.prdc.coverage                           0.0065
# stats.survival_km_distance.optimism           0.0035
# stats.survival_km_distance.abs_optimism       0.0015
# stats.survival_km_distance.sightedness        0.0060
# performance.linear_model.gt.c_index           0.0000
# performance.linear_model.gt.brier_score       0.0000
# performance.linear_model.syn_id.c_index       0.0021
# performance.linear_model.syn_id.brier_score   0.0006
# performance.linear_model.syn_ood.c_index      0.0022
# performance.linear_model.syn_ood.brier_score  0.0008
# performance.mlp.gt.c_index                    0.0000
# performance.mlp.gt.brier_score                0.0000
# performance.mlp.syn_id.c_index                0.0136
# performance.mlp.syn_id.brier_score            0.0028
# performance.mlp.syn_ood.c_index               0.0134
# performance.mlp.syn_ood.brier_score           0.0023
# performance.xgb.gt.c_index                    0.0004
# performance.xgb.gt.brier_score                0.0001
# performance.xgb.syn_id.c_index                0.0021
# performance.xgb.syn_id.brier_score            0.0003
# performance.xgb.syn_ood.c_index               0.0011
# performance.xgb.syn_ood.brier_score           0.0005

# %%
p_values_df
# Out:
#              x0            x1            x2            x3            x8  \
# 0  4.485423e-13  4.179717e-34  3.037475e-38  6.253011e-52  4.600830e-33
# 1  1.170342e-13  2.278491e-34  6.292248e-38  7.383384e-52  6.863909e-34
# 2  3.031940e-13  3.971650e-32  1.036340e-38  4.214538e-53  4.679554e-36
# 3  1.762658e-13  1.757810e-34  2.833987e-37  6.288411e-51  3.014409e-36
# 4  4.155925e-13  3.256996e-32  9.842594e-39  9.049426e-51  1.987569e-35
#
#          x4        x5        x6        x7
# 0  0.394441  1.000000  0.127821  0.739378
# 1  0.144465  0.947125  0.331931  0.370634
# 2  0.052951  1.000000  0.031412  0.844900
# 3  0.067842  0.720010  0.245220  0.841839
# 4  0.460579  0.573296  0.679005  0.417389

# %% [markdown]
# # GBSG

# %%
dataset="gbsg"

metrics_list = []
fit_times = []
generate_times = []
p_values_list = []

for i in range(5):
    df = datasets.gbsg.read_df()
    df = df[df['duration'] != 0]

    syn_model = Plugins().get(plugin_name)
    X=df
    # Measure the execution time of the fit function
    start = timer()
    syn_model.fit(X)
    fit_time = timer() - start
    fit_times.append(fit_time)

    random_state = i + 1
    np.random.seed(random_state)

    # Measure the execution time of the generate function
    start = timer()
    X_gen = syn_model.generate(count=len(df)).dataframe()
    generate_time = timer() - start
    generate_times.append(generate_time)

    # Save X_gen as a CSV file
    X_gen.to_csv(f"/content/drive/MyDrive/Nips/{dataset}_{plugin_name}_nocond_iteration_{i+1}.csv", index=False)

    loader1 = SurvivalAnalysisDataLoader(df, target_column="event", time_to_event_column="duration")
    loader2 = SurvivalAnalysisDataLoader(X_gen, target_column="event", time_to_event_column="duration")

    met_df = Metrics.evaluate(X_gt=loader1, X_syn=loader2, task_type='survival_analysis', metrics={
        'stats': ['jensenshannon_dist', 'chi_squared_test', 'feature_corr', 'inv_kl_divergence', 'ks_test',
                 'max_mean_discrepancy', 'wasserstein_dist', 'prdc', 'alpha_precision', 'survival_km_distance'],
        'performance': ['linear_model', 'mlp', 'xgb', 'feat_rank_distance']
    }, use_cache=False, random_state=random_state)

    met_df = met_df.iloc[:, 0]
    metrics_list.append(met_df)

    # Calculate p-values
    p_values_continuous, p_values_discrete = compare_distributions(df, X_gen)
    continuous_column_names = list(p_values_continuous.keys())
    discrete_column_names = list(p_values_discrete.keys())

    p_val = np.concatenate([list(p_values_continuous.values()), list(p_values_discrete.values())])
    p_values_list.append(p_val)

    workspace_dir = os.path.join(os.getcwd(), 'workspace')
    if os.path.exists(workspace_dir):
        shutil.rmtree(workspace_dir)

result_df = pd.concat(metrics_list, axis=1)

# Calculate the row-wise mean and standard deviation of the metrics
result_df['Mean'] = result_df.mean(axis=1)
result_df['Std'] = result_df.std(axis=1)
result_df['Std'] = result_df['Std'].round(4)

# Create DataFrame for p-values
p_values_df = pd.DataFrame(p_values_list, columns=continuous_column_names + discrete_column_names)

# Save result_df and p_values_df as CSV files
result_df.to_csv(f"/content/drive/MyDrive/Nips/{dataset}_{plugin_name}_nocond_result_df.csv")
p_values_df.to_csv(f"/content/drive/MyDrive/Nips/{dataset}_{plugin_name}_nocond_p_values_df.csv")

avg_fit_time = np.mean(fit_times)
avg_generate_time = np.mean(generate_times)
std_fit_time = np.std(fit_times)
std_generate_time = np.std(generate_times)

print(f"\nAverage Fit Time: {avg_fit_time:.4f} seconds, Standard Deviation: {std_fit_time:.4f} seconds")
print(f"Average Generate Time: {avg_generate_time:.4f} seconds, Standard Deviation: {std_generate_time:.4f} seconds")
# Out:
# Dataset 'gbsg' not locally available. Downloading...
# [2024-04-20T00:37:34.586479+0000][1377][CRITICAL] module disabled: /usr/local/lib/python3.10/dist-packages/synthcity/plugins/generic/plugin_goggle.py
# Done
#  50%|████▉     | 999/2000 [04:45<04:45,  3.50it/s]
# [2024-04-20T00:44:19.996323+0000][1377][CRITICAL] module disabled: /usr/local/lib/python3.10/dist-packages/synthcity/plugins/generic/plugin_goggle.py
#  50%|████▉     | 999/2000 [04:44<04:45,  3.51it/s]
# [2024-04-20T00:51:05.033608+0000][1377][CRITICAL] module disabled: /usr/local/lib/python3.10/dist-packages/synthcity/plugins/generic/plugin_goggle.py
#  50%|████▉     | 999/2000 [04:46<04:47,  3.48it/s]
# [2024-04-20T00:57:52.104107+0000][1377][CRITICAL] module disabled: /usr/local/lib/python3.10/dist-packages/synthcity/plugins/generic/plugin_goggle.py
#  50%|████▉     | 999/2000 [04:44<04:44,  3.51it/s]
# [2024-04-20T01:04:35.913003+0000][1377][CRITICAL] module disabled: /usr/local/lib/python3.10/dist-packages/synthcity/plugins/generic/plugin_goggle.py
#  50%|████▉     | 999/2000 [04:43<04:43,  3.53it/s]
# Average Fit Time: 287.4944 seconds, Standard Deviation: 1.4224 seconds
# Average Generate Time: 0.0730 seconds, Standard Deviation: 0.0023 seconds

# %%
result_df
# Out:
#                                                    min       min       min  \
# stats.jensenshannon_dist.marginal             0.009117  0.008550  0.008749
# stats.chi_squared_test.marginal               0.522624  0.482485  0.512003
# stats.inv_kl_divergence.marginal              0.925917  0.934726  0.937446
# stats.ks_test.marginal                        0.898994  0.903325  0.900936
# stats.max_mean_discrepancy.joint              0.000898  0.000899  0.000899
# stats.wasserstein_dist.joint                  0.017127  0.016850  0.017187
# stats.prdc.precision                          0.993728  0.994624  0.994624
# stats.prdc.recall                             0.893817  0.898297  0.892921
# stats.prdc.density                            0.985036  0.992025  0.992204
# stats.prdc.coverage                           0.779570  0.780914  0.785842
# stats.survival_km_distance.optimism           0.060184  0.058695  0.060397
# stats.survival_km_distance.abs_optimism       0.061135  0.060584  0.061862
# stats.survival_km_distance.sightedness        0.000000  0.000000  0.000000
# performance.linear_model.gt.c_index           0.678109  0.678109  0.678109
# performance.linear_model.gt.brier_score       0.204760  0.204760  0.204760
# performance.linear_model.syn_id.c_index       0.688620  0.687742  0.686893
# performance.linear_model.syn_id.brier_score   0.203735  0.204408  0.204598
# performance.linear_model.syn_ood.c_index      0.670599  0.669512  0.673477
# performance.linear_model.syn_ood.brier_score  0.210393  0.210983  0.210508
# performance.mlp.gt.c_index                    0.575017  0.575017  0.575017
# performance.mlp.gt.brier_score                0.238290  0.238290  0.238290
# performance.mlp.syn_id.c_index                0.603150  0.620789  0.585869
# performance.mlp.syn_id.brier_score            0.222057  0.217286  0.227658
# performance.mlp.syn_ood.c_index               0.575013  0.500000  0.599221
# performance.mlp.syn_ood.brier_score           0.229225  0.234760  0.227026
# performance.xgb.gt.c_index                    0.695324  0.695443  0.694734
# performance.xgb.gt.brier_score                0.205717  0.205379  0.205685
# performance.xgb.syn_id.c_index                0.695168  0.695946  0.699956
# performance.xgb.syn_id.brier_score            0.206178  0.205766  0.205173
# performance.xgb.syn_ood.c_index               0.662714  0.664221  0.669052
# performance.xgb.syn_ood.brier_score           0.215174  0.214731  0.214095
#
#                                                    min       min      Mean  \
# stats.jensenshannon_dist.marginal             0.009098  0.008774  0.008858
# stats.chi_squared_test.marginal               0.521355  0.511565  0.510006
# stats.inv_kl_divergence.marginal              0.938412  0.937871  0.934874
# stats.ks_test.marginal                        0.899791  0.901085  0.900826
# stats.max_mean_discrepancy.joint              0.000899  0.000899  0.000899
# stats.wasserstein_dist.joint                  0.017678  0.016298  0.017028
# stats.prdc.precision                          0.993280  0.994176  0.994086
# stats.prdc.recall                             0.891577  0.876344  0.890591
# stats.prdc.density                            0.996326  0.986201  0.990358
# stats.prdc.coverage                           0.772401  0.769713  0.777688
# stats.survival_km_distance.optimism           0.062247  0.059491  0.060203
# stats.survival_km_distance.abs_optimism       0.063539  0.060916  0.061607
# stats.survival_km_distance.sightedness        0.000000  0.000000  0.000000
# performance.linear_model.gt.c_index           0.678109  0.678109  0.678109
# performance.linear_model.gt.brier_score       0.204760  0.204760  0.204760
# performance.linear_model.syn_id.c_index       0.687729  0.689340  0.688065
# performance.linear_model.syn_id.brier_score   0.204450  0.204361  0.204310
# performance.linear_model.syn_ood.c_index      0.670386  0.672552  0.671305
# performance.linear_model.syn_ood.brier_score  0.211560  0.210499  0.210789
# performance.mlp.gt.c_index                    0.575017  0.575017  0.575017
# performance.mlp.gt.brier_score                0.238290  0.238290  0.238290
# performance.mlp.syn_id.c_index                0.588761  0.592701  0.598254
# performance.mlp.syn_id.brier_score            0.227918  0.222803  0.223544
# performance.mlp.syn_ood.c_index               0.549274  0.578710  0.560444
# performance.mlp.syn_ood.brier_score           0.231743  0.227021  0.229955
# performance.xgb.gt.c_index                    0.695615  0.694891  0.695201
# performance.xgb.gt.brier_score                0.205547  0.205396  0.205545
# performance.xgb.syn_id.c_index                0.697095  0.696468  0.696926
# performance.xgb.syn_id.brier_score            0.205123  0.205729  0.205594
# performance.xgb.syn_ood.c_index               0.667636  0.662365  0.665198
# performance.xgb.syn_ood.brier_score           0.213232  0.214721  0.214391
#
#                                                  Std
# stats.jensenshannon_dist.marginal             0.0002
# stats.chi_squared_test.marginal               0.0145
# stats.inv_kl_divergence.marginal              0.0047
# stats.ks_test.marginal                        0.0015
# stats.max_mean_discrepancy.joint              0.0000
# stats.wasserstein_dist.joint                  0.0005
# stats.prdc.precision                          0.0005
# stats.prdc.recall                             0.0075
# stats.prdc.density                            0.0042
# stats.prdc.coverage                           0.0059
# stats.survival_km_distance.optimism           0.0012
# stats.survival_km_distance.abs_optimism       0.0011
# stats.survival_km_distance.sightedness        0.0000
# performance.linear_model.gt.c_index           0.0000
# performance.linear_model.gt.brier_score       0.0000
# performance.linear_model.syn_id.c_index       0.0008
# performance.linear_model.syn_id.brier_score   0.0003
# performance.linear_model.syn_ood.c_index      0.0015
# performance.linear_model.syn_ood.brier_score  0.0004
# performance.mlp.gt.c_index                    0.0000
# performance.mlp.gt.brier_score                0.0000
# performance.mlp.syn_id.c_index                0.0127
# performance.mlp.syn_id.brier_score            0.0039
# performance.mlp.syn_ood.c_index               0.0341
# performance.mlp.syn_ood.brier_score           0.0030
# performance.xgb.gt.c_index                    0.0003
# performance.xgb.gt.brier_score                0.0001
# performance.xgb.syn_id.c_index                0.0016
# performance.xgb.syn_id.brier_score            0.0004
# performance.xgb.syn_ood.c_index               0.0027
# performance.xgb.syn_ood.brier_score           0.0007

# %%
p_values_df
# Out:
#          x3        x4            x5            x6        x0        x1  \
# 0  0.221038  0.127862  7.235115e-09  9.480833e-10  0.038887  0.352351
# 1  0.356394  0.052472  7.559601e-09  1.088234e-09  0.246401  0.281872
# 2  0.275710  0.041214  1.269046e-08  1.116360e-09  0.238060  0.330919
# 3  0.248111  0.127376  1.051723e-08  8.373663e-09  0.333071  0.227022
# 4  0.280662  0.107970  2.695925e-08  1.176554e-08  0.460186  0.473726
#
#          x2
# 0  1.000000
# 1  0.149961
# 2  0.773334
# 3  0.718208
# 4  0.594067

# %% [markdown]
# # SUPPORT

# %%
dataset="support"

metrics_list = []
fit_times = []
generate_times = []
p_values_list = []

for i in range(5):
    df = datasets.support.read_df()
    df = df[df['duration'] != 0]

    syn_model = Plugins().get(plugin_name)
    X=df
    # Measure the execution time of the fit function
    start = timer()
    syn_model.fit(X)
    fit_time = timer() - start
    fit_times.append(fit_time)

    random_state = i + 1
    np.random.seed(random_state)

    # Measure the execution time of the generate function
    start = timer()
    X_gen = syn_model.generate(count=len(df)).dataframe()
    generate_time = timer() - start
    generate_times.append(generate_time)

    # Save X_gen as a CSV file
    X_gen.to_csv(f"/content/drive/MyDrive/Nips/{dataset}_{plugin_name}_nocond_iteration_{i+1}.csv", index=False)

    loader1 = SurvivalAnalysisDataLoader(df, target_column="event", time_to_event_column="duration")
    loader2 = SurvivalAnalysisDataLoader(X_gen, target_column="event", time_to_event_column="duration")

    met_df = Metrics.evaluate(X_gt=loader1, X_syn=loader2, task_type='survival_analysis', metrics={
        'stats': ['jensenshannon_dist', 'chi_squared_test', 'feature_corr', 'inv_kl_divergence', 'ks_test',
                 'max_mean_discrepancy', 'wasserstein_dist', 'prdc', 'alpha_precision', 'survival_km_distance'],
        'performance': ['linear_model', 'mlp', 'xgb', 'feat_rank_distance']
    }, use_cache=False, random_state=random_state)

    met_df = met_df.iloc[:, 0]
    metrics_list.append(met_df)

    # Calculate p-values
    p_values_continuous, p_values_discrete = compare_distributions(df, X_gen)
    continuous_column_names = list(p_values_continuous.keys())
    discrete_column_names = list(p_values_discrete.keys())

    p_val = np.concatenate([list(p_values_continuous.values()), list(p_values_discrete.values())])
    p_values_list.append(p_val)

    workspace_dir = os.path.join(os.getcwd(), 'workspace')
    if os.path.exists(workspace_dir):
        shutil.rmtree(workspace_dir)

result_df = pd.concat(metrics_list, axis=1)

# Calculate the row-wise mean and standard deviation of the metrics
result_df['Mean'] = result_df.mean(axis=1)
result_df['Std'] = result_df.std(axis=1)
result_df['Std'] = result_df['Std'].round(4)

# Create DataFrame for p-values
p_values_df = pd.DataFrame(p_values_list, columns=continuous_column_names + discrete_column_names)

# Save result_df and p_values_df as CSV files
result_df.to_csv(f"/content/drive/MyDrive/Nips/{dataset}_{plugin_name}_nocond_result_df.csv")
p_values_df.to_csv(f"/content/drive/MyDrive/Nips/{dataset}_{plugin_name}_nocond_p_values_df.csv")

avg_fit_time = np.mean(fit_times)
avg_generate_time = np.mean(generate_times)
std_fit_time = np.std(fit_times)
std_generate_time = np.std(generate_times)

print(f"\nAverage Fit Time: {avg_fit_time:.4f} seconds, Standard Deviation: {std_fit_time:.4f} seconds")
print(f"Average Generate Time: {avg_generate_time:.4f} seconds, Standard Deviation: {std_generate_time:.4f} seconds")
# Out:
# Dataset 'support' not locally available. Downloading...
# Done
# [2024-04-20T09:10:11.458726+0000][2633][CRITICAL] module disabled: /usr/local/lib/python3.10/dist-packages/synthcity/plugins/generic/plugin_goggle.py
#  20%|█▉        | 399/2000 [08:10<32:46,  1.23s/it]
# [KeOps] Generating code for Max_SumShiftExpWeight_Reduction reduction (with parameters 0) of formula [c-1/2*(d*Sum((a-b)**2)),1] with a=Var(0,16,0), b=Var(1,16,1), c=Var(2,1,1), d=Var(3,1,2) ... OK
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [2024-04-20T09:23:05.773820+0000][2633][CRITICAL] module disabled: /usr/local/lib/python3.10/dist-packages/synthcity/plugins/generic/plugin_goggle.py
#  20%|█▉        | 399/2000 [08:32<34:16,  1.28s/it]
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [2024-04-20T09:36:00.329455+0000][2633][CRITICAL] module disabled: /usr/local/lib/python3.10/dist-packages/synthcity/plugins/generic/plugin_goggle.py
#  20%|█▉        | 399/2000 [08:43<35:01,  1.31s/it]
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [2024-04-20T09:49:05.604950+0000][2633][CRITICAL] module disabled: /usr/local/lib/python3.10/dist-packages/synthcity/plugins/generic/plugin_goggle.py
#  20%|█▉        | 399/2000 [08:30<34:09,  1.28s/it]
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [2024-04-20T10:01:52.083277+0000][2633][CRITICAL] module disabled: /usr/local/lib/python3.10/dist-packages/synthcity/plugins/generic/plugin_goggle.py
#  20%|█▉        | 399/2000 [08:31<34:13,  1.28s/it]
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
#
# Average Fit Time: 523.6260 seconds, Standard Deviation: 5.6088 seconds
# Average Generate Time: 0.1924 seconds, Standard Deviation: 0.0357 seconds

# %%
result_df
# Out:
#                                                    min       min       min  \
# stats.jensenshannon_dist.marginal             0.004982  0.005033  0.004966
# stats.chi_squared_test.marginal               0.742279  0.741677  0.679545
# stats.inv_kl_divergence.marginal              0.968301  0.968099  0.968104
# stats.ks_test.marginal                        0.933393  0.933041  0.933154
# stats.max_mean_discrepancy.joint              0.000225  0.000225  0.000225
# stats.wasserstein_dist.joint                  0.036289  0.036568  0.036415
# stats.prdc.precision                          0.971599  0.971825  0.969683
# stats.prdc.recall                             0.916601  0.918517  0.920545
# stats.prdc.density                            1.036966  1.037191  1.033247
# stats.prdc.coverage                           0.896427  0.895638  0.899696
# stats.survival_km_distance.optimism          -0.039772 -0.037792 -0.038184
# stats.survival_km_distance.abs_optimism       0.039772  0.037819  0.038184
# stats.survival_km_distance.sightedness        0.006954  0.015853  0.009537
# performance.linear_model.gt.c_index           0.568899  0.568899  0.568899
# performance.linear_model.gt.brier_score       0.208247  0.208247  0.208247
# performance.linear_model.syn_id.c_index       0.561423  0.561542  0.561147
# performance.linear_model.syn_id.brier_score   0.211135  0.210882  0.210725
# performance.linear_model.syn_ood.c_index      0.575544  0.576728  0.576395
# performance.linear_model.syn_ood.brier_score  0.210540  0.209985  0.209913
# performance.mlp.gt.c_index                    0.520378  0.520378  0.520378
# performance.mlp.gt.brier_score                0.219523  0.219523  0.219523
# performance.mlp.syn_id.c_index                0.502287  0.500789  0.530506
# performance.mlp.syn_id.brier_score            0.219458  0.218967  0.218532
# performance.mlp.syn_ood.c_index               0.560144  0.500140  0.500000
# performance.mlp.syn_ood.brier_score           0.219538  0.220250  0.220333
# performance.xgb.gt.c_index                    0.613365  0.613776  0.613345
# performance.xgb.gt.brier_score                0.195653  0.195389  0.195561
# performance.xgb.syn_id.c_index                0.595993  0.594138  0.596027
# performance.xgb.syn_id.brier_score            0.202827  0.203175  0.202525
# performance.xgb.syn_ood.c_index               0.605607  0.606082  0.607392
# performance.xgb.syn_ood.brier_score           0.203907  0.203886  0.203991
#
#                                                    min       min      Mean  \
# stats.jensenshannon_dist.marginal             0.005017  0.004978  0.004995
# stats.chi_squared_test.marginal               0.742122  0.741909  0.729507
# stats.inv_kl_divergence.marginal              0.968070  0.968135  0.968142
# stats.ks_test.marginal                        0.933464  0.933302  0.933271
# stats.max_mean_discrepancy.joint              0.000225  0.000225  0.000225
# stats.wasserstein_dist.joint                  0.036270  0.036611  0.036431
# stats.prdc.precision                          0.971487  0.971036  0.971126
# stats.prdc.recall                             0.916826  0.918291  0.918156
# stats.prdc.density                            1.035929  1.035276  1.035722
# stats.prdc.coverage                           0.896540  0.896315  0.896923
# stats.survival_km_distance.optimism          -0.037204 -0.040267 -0.038644
# stats.survival_km_distance.abs_optimism       0.037204  0.040267  0.038649
# stats.survival_km_distance.sightedness        0.009537  0.009537  0.010284
# performance.linear_model.gt.c_index           0.568899  0.568899  0.568899
# performance.linear_model.gt.brier_score       0.208247  0.208247  0.208247
# performance.linear_model.syn_id.c_index       0.561440  0.560765  0.561263
# performance.linear_model.syn_id.brier_score   0.210721  0.210700  0.210833
# performance.linear_model.syn_ood.c_index      0.576399  0.575657  0.576144
# performance.linear_model.syn_ood.brier_score  0.209975  0.210134  0.210109
# performance.mlp.gt.c_index                    0.520378  0.520378  0.520378
# performance.mlp.gt.brier_score                0.219523  0.219523  0.219523
# performance.mlp.syn_id.c_index                0.499844  0.557624  0.518210
# performance.mlp.syn_id.brier_score            0.219003  0.217367  0.218665
# performance.mlp.syn_ood.c_index               0.551906  0.546341  0.531706
# performance.mlp.syn_ood.brier_score           0.217097  0.220373  0.219518
# performance.xgb.gt.c_index                    0.612465  0.613834  0.613357
# performance.xgb.gt.brier_score                0.195665  0.195373  0.195528
# performance.xgb.syn_id.c_index                0.595778  0.594057  0.595199
# performance.xgb.syn_id.brier_score            0.202687  0.203391  0.202921
# performance.xgb.syn_ood.c_index               0.605643  0.608129  0.606571
# performance.xgb.syn_ood.brier_score           0.203938  0.203712  0.203887
#
#                                                  Std
# stats.jensenshannon_dist.marginal             0.0000
# stats.chi_squared_test.marginal               0.0250
# stats.inv_kl_divergence.marginal              0.0001
# stats.ks_test.marginal                        0.0002
# stats.max_mean_discrepancy.joint              0.0000
# stats.wasserstein_dist.joint                  0.0001
# stats.prdc.precision                          0.0008
# stats.prdc.recall                             0.0014
# stats.prdc.density                            0.0014
# stats.prdc.coverage                           0.0014
# stats.survival_km_distance.optimism           0.0012
# stats.survival_km_distance.abs_optimism       0.0012
# stats.survival_km_distance.sightedness        0.0030
# performance.linear_model.gt.c_index           0.0000
# performance.linear_model.gt.brier_score       0.0000
# performance.linear_model.syn_id.c_index       0.0003
# performance.linear_model.syn_id.brier_score   0.0002
# performance.linear_model.syn_ood.c_index      0.0005
# performance.linear_model.syn_ood.brier_score  0.0002
# performance.mlp.gt.c_index                    0.0000
# performance.mlp.gt.brier_score                0.0000
# performance.mlp.syn_id.c_index                0.0228
# performance.mlp.syn_id.brier_score            0.0007
# performance.mlp.syn_ood.c_index               0.0262
# performance.mlp.syn_ood.brier_score           0.0012
# performance.xgb.gt.c_index                    0.0005
# performance.xgb.gt.brier_score                0.0001
# performance.xgb.syn_id.c_index                0.0009
# performance.xgb.syn_id.brier_score            0.0003
# performance.xgb.syn_ood.c_index               0.0010
# performance.xgb.syn_ood.brier_score           0.0001

# %%
p_values_df
# Out:
#          x0            x7            x8        x9           x10       x11  \
# 0  0.726121  3.310172e-12  1.548332e-36  0.001049  3.059714e-59  0.050561
# 1  0.823218  3.828446e-12  7.179075e-37  0.001328  1.832767e-59  0.035229
# 2  0.804119  6.815560e-13  1.530907e-36  0.001206  1.014069e-59  0.043853
# 3  0.978721  8.747006e-13  7.895356e-35  0.000542  1.655767e-58  0.050156
# 4  0.764374  8.559673e-13  2.005448e-34  0.003090  1.469340e-59  0.054052
#
#         x12           x13        x1        x2        x3        x4        x5  \
# 0  0.027578  5.139781e-31  0.776252  0.902419  0.940691  0.974938  0.915735
# 1  0.032326  6.934507e-31  0.691674  0.286341  0.880353  0.712349  1.000000
# 2  0.031378  2.503547e-31  0.395874  0.963978  0.893514  0.474400  1.000000
# 3  0.037892  4.932098e-31  0.707631  0.262724  0.841616  0.855166  0.947947
# 4  0.015606  1.304853e-31  0.697730  0.967451  0.857312  0.762023  0.555978
#
#          x6
# 0  0.876670
# 1  0.864436
# 2  0.905785
# 3  0.967275
# 4  0.896069
