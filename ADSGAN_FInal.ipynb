# %%
# !pip install git+https://github.com/Ashhad785/synthcity.git

# %%
# !pip uninstall -y torchaudio torchdata
# !pip install pycox
from pycox import datasets
from synthcity.metrics import Metrics
from synthcity.plugins.core.dataloader import SurvivalAnalysisDataLoader
import numpy as np
import pandas as pd
import os
import shutil
from timeit import default_timer as timer
from synthcity.plugins import Plugins
# Out:
# [KeOps] Compiling cuda jit compiler engine ... OK
# [pyKeOps] Compiling nvrtc binder for python ... OK

# %%
plugin_name="adsgan"

# %% [markdown]
# # Functions

# %%
def sinusoidal_embedding(values, event_indicators, embedding_dim):
    # Find the unique values and sort them
    unique_values = sorted(set(values))

    # Create a dictionary to map values to their indices
    value_to_idx = {value: idx for idx, value in enumerate(unique_values)}

    # Create the embedding matrix
    embeddings = np.zeros((len(unique_values), embedding_dim + 1))

    # Assign sinusoidal embeddings based on the order of values
    for idx, value in enumerate(unique_values):
        for j in range(embedding_dim // 2):
            embeddings[idx, 2 * j] = np.sin(idx / (10000 ** (2 * j / embedding_dim)))
            embeddings[idx, 2 * j + 1] = np.cos(idx / (10000 ** (2 * j / embedding_dim)))

    # Map the input values to their embeddings
    value_embeddings = []
    for value, event_indicator in zip(values, event_indicators):
        embedding = embeddings[value_to_idx[value]].copy()
        embedding[-1] = event_indicator
        value_embeddings.append(embedding)

    return np.array(value_embeddings)


from scipy.stats import mannwhitneyu, chi2_contingency,wilcoxon
import matplotlib.pyplot as plt

def identify_variable_types(df):
    continuous_columns = []
    discrete_columns = []

    for col in df.columns:
        unique_vals = df[col].unique()
        num_unique = len(unique_vals)
        if num_unique > 20:  # Threshold for considering a column as continuous
            continuous_columns.append(col)
        else:
            discrete_columns.append(col)

    return continuous_columns, discrete_columns

def compare_distributions(real_df, synthetic_df, alpha=0.05):
    real_df = real_df.drop(['duration', 'event'], axis=1)
    real_continuous, real_discrete = identify_variable_types(real_df)
    p_values_continuous = {}
    p_values_discrete = {}

    synthetic_df = synthetic_df.drop(['duration', 'event'], axis=1)
    synthetic_continuous, synthetic_discrete = identify_variable_types(synthetic_df)

    synthetic_continuous = [col for col in synthetic_continuous if col not in ["event", "duration"]]
    synthetic_discrete = [col for col in synthetic_discrete if col not in ["event", "duration"]]

    # Wilcoxon rank-sum test for continuous variables
    for col in real_continuous:
        if col in synthetic_continuous:
            _, p_value = mannwhitneyu(real_df[col], synthetic_df[col])
            p_values_continuous[col] = p_value

    # Chi-square test for discrete variables
    for col in real_discrete:
        if col in synthetic_discrete:
            contingency_table = pd.crosstab(real_df[col], synthetic_df[col])
            _, p, _, _ = chi2_contingency(contingency_table)
            p_values_discrete[col] = p

    # Plot p-values
    # plt.figure(figsize=(10, 6))

    # continuous_p_values = {col: p_values_continuous[col] for col in real_continuous}
    # discrete_p_values = {col: p_values_discrete[col] for col in real_discrete}

    # plt.plot(list(continuous_p_values.keys()), list(continuous_p_values.values()), label='Continuous', marker='o')
    # plt.plot(list(discrete_p_values.keys()), list(discrete_p_values.values()), label='Discrete', marker='o', linestyle='dashed')

    # # Plot alpha line
    # plt.axhline(y=alpha, color='red', linestyle='--', label=f'alpha = {alpha}')

    # plt.xlabel('Column Name')
    # plt.ylabel('p-value')
    # plt.title('Comparison of p-values for Real and Synthetic Data')
    # plt.xticks(rotation=45)
    # plt.legend()
    # plt.grid(True)
    # plt.tight_layout()
    # plt.show()

    return p_values_continuous, p_values_discrete

# %% [markdown]
# # FLCHAIN

# %%
dataset="flchain"

metrics_list = []
fit_times = []
generate_times = []
p_values_list = []

for i in range(5):
    df = pd.read_csv('/content/drive/MyDrive/Datasets/flchain_final.csv')
    df = df.drop('Unnamed: 0', axis=1)
    df = df[df['duration'] != 0]

    time = df['duration'].to_list()
    event = df['event'].to_list()

    time_event_encoded = sinusoidal_embedding(time, event, 4)
    X = df.drop(['duration', 'event'], axis=1)
    y = time_event_encoded

    syn_model = Plugins().get(plugin_name)

    # Measure the execution time of the fit function
    start = timer()
    syn_model.fit(X, cond=y)
    fit_time = timer() - start
    fit_times.append(fit_time)

    survival_df=df
    event_0_data = survival_df[survival_df['event'] == 0]['duration']
    event_1_data = survival_df[survival_df['event'] == 1]['duration']

    random_state = i + 1
    np.random.seed(random_state)

    sample_size_0 = len(event_0_data)
    sample_size_1= len(event_1_data)
    sample_event_0 = np.random.choice(event_0_data, size=sample_size_0)
    sample_event_1 = np.random.choice(event_1_data, size=sample_size_1)

    z=np.concatenate([sample_event_0,sample_event_1])
    x=np.zeros(len(sample_event_0))
    y=np.ones(len(sample_event_1))
    p=np.concatenate([x,y])

    time_event_gen_encoded=sinusoidal_embedding(z,p,4)

    # Measure the execution time of the generate function
    start = timer()
    X_gen = syn_model.generate(count=len(df), cond=np.array(time_event_gen_encoded)).dataframe()
    generate_time = timer() - start
    generate_times.append(generate_time)

    X_gen['duration'] = z
    X_gen['event'] = p
    X_gen = X_gen.sample(frac=1).reset_index(drop=True)

    # Save X_gen as a CSV file
    X_gen.to_csv(f"/content/drive/MyDrive/Nips/{dataset}_{plugin_name}_iteration_{i+1}.csv", index=False)

    loader1 = SurvivalAnalysisDataLoader(df, target_column="event", time_to_event_column="duration")
    loader2 = SurvivalAnalysisDataLoader(X_gen, target_column="event", time_to_event_column="duration")

    met_df = Metrics.evaluate(X_gt=loader1, X_syn=loader2, task_type='survival_analysis', metrics={
        'stats': ['jensenshannon_dist', 'chi_squared_test', 'feature_corr', 'inv_kl_divergence', 'ks_test',
                 'max_mean_discrepancy', 'wasserstein_dist', 'prdc', 'alpha_precision', 'survival_km_distance'],
        'performance': ['linear_model', 'mlp', 'xgb', 'feat_rank_distance']
    }, use_cache=False, random_state=random_state)

    met_df = met_df.iloc[:, 0]
    metrics_list.append(met_df)

    # Calculate p-values
    p_values_continuous, p_values_discrete = compare_distributions(df, X_gen)
    continuous_column_names = list(p_values_continuous.keys())
    discrete_column_names = list(p_values_discrete.keys())

    p_val = np.concatenate([list(p_values_continuous.values()), list(p_values_discrete.values())])
    p_values_list.append(p_val)

    workspace_dir = os.path.join(os.getcwd(), 'workspace')
    if os.path.exists(workspace_dir):
        shutil.rmtree(workspace_dir)

result_df = pd.concat(metrics_list, axis=1)

# Calculate the row-wise mean and standard deviation of the metrics
result_df['Mean'] = result_df.mean(axis=1)
result_df['Std'] = result_df.std(axis=1)
result_df['Std'] = result_df['Std'].round(4)

# Create DataFrame for p-values
p_values_df = pd.DataFrame(p_values_list, columns=continuous_column_names + discrete_column_names)

# Save result_df and p_values_df as CSV files
result_df.to_csv(f"/content/drive/MyDrive/Nips/{dataset}_{plugin_name}_result_df.csv")
p_values_df.to_csv(f"/content/drive/MyDrive/Nips/{dataset}_{plugin_name}_p_values_df.csv")

avg_fit_time = np.mean(fit_times)
avg_generate_time = np.mean(generate_times)
std_fit_time = np.std(fit_times)
std_generate_time = np.std(generate_times)

print(f"\nAverage Fit Time: {avg_fit_time:.4f} seconds, Standard Deviation: {std_fit_time:.4f} seconds")
print(f"Average Generate Time: {avg_generate_time:.4f} seconds, Standard Deviation: {std_generate_time:.4f} seconds")
# Out:
# [2024-04-19T17:08:59.949542+0000][4342][CRITICAL] module disabled: /usr/local/lib/python3.10/dist-packages/synthcity/plugins/generic/plugin_goggle.py
#   4%|▍         | 449/10000 [06:23<2:16:01,  1.17it/s]
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [2024-04-19T17:21:29.441544+0000][4342][CRITICAL] module disabled: /usr/local/lib/python3.10/dist-packages/synthcity/plugins/generic/plugin_goggle.py
#   6%|▋         | 649/10000 [09:25<2:15:43,  1.15it/s]
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [2024-04-19T17:36:51.338652+0000][4342][CRITICAL] module disabled: /usr/local/lib/python3.10/dist-packages/synthcity/plugins/generic/plugin_goggle.py
#   6%|▋         | 649/10000 [09:28<2:16:34,  1.14it/s]
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [2024-04-19T17:52:24.763239+0000][4342][CRITICAL] module disabled: /usr/local/lib/python3.10/dist-packages/synthcity/plugins/generic/plugin_goggle.py
#   6%|▋         | 649/10000 [09:35<2:18:19,  1.13it/s]
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [2024-04-19T18:08:22.546896+0000][4342][CRITICAL] module disabled: /usr/local/lib/python3.10/dist-packages/synthcity/plugins/generic/plugin_goggle.py
#   6%|▋         | 649/10000 [09:30<2:17:02,  1.14it/s]
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
#
# Average Fit Time: 535.8305 seconds, Standard Deviation: 74.3194 seconds
# Average Generate Time: 0.1022 seconds, Standard Deviation: 0.0177 seconds

# %%
result_df
# Out:
#                                                    min       min       min  \
# stats.jensenshannon_dist.marginal             0.004688  0.003886  0.004009
# stats.chi_squared_test.marginal               0.537957  0.538145  0.538435
# stats.inv_kl_divergence.marginal              0.934386  0.940985  0.940426
# stats.ks_test.marginal                        0.845301  0.890218  0.889294
# stats.max_mean_discrepancy.joint              0.000262  0.000261  0.000260
# stats.wasserstein_dist.joint                  0.021154  0.017659  0.017918
# stats.prdc.precision                          0.930250  0.935332  0.935713
# stats.prdc.recall                             0.979672  0.984627  0.982594
# stats.prdc.density                            0.817939  0.838979  0.837251
# stats.prdc.coverage                           0.909414  0.918816  0.917037
# stats.survival_km_distance.optimism           0.002841 -0.000455  0.002393
# stats.survival_km_distance.abs_optimism       0.003342  0.001250  0.002706
# stats.survival_km_distance.sightedness        0.000000  0.000000  0.000000
# performance.linear_model.gt.c_index           0.864923  0.864923  0.864923
# performance.linear_model.gt.brier_score       0.086823  0.086823  0.086823
# performance.linear_model.syn_id.c_index       0.862796  0.864625  0.865697
# performance.linear_model.syn_id.brier_score   0.087260  0.088313  0.088128
# performance.linear_model.syn_ood.c_index      0.874371  0.874901  0.875431
# performance.linear_model.syn_ood.brier_score  0.085829  0.087851  0.088093
# performance.mlp.gt.c_index                    0.798863  0.798863  0.798863
# performance.mlp.gt.brier_score                0.094956  0.094956  0.094956
# performance.mlp.syn_id.c_index                0.851260  0.845848  0.849713
# performance.mlp.syn_id.brier_score            0.094522  0.090794  0.084241
# performance.mlp.syn_ood.c_index               0.854138  0.773883  0.811272
# performance.mlp.syn_ood.brier_score           0.102201  0.095935  0.102588
# performance.xgb.gt.c_index                    0.869622  0.870668  0.871006
# performance.xgb.gt.brier_score                0.094515  0.093983  0.093696
# performance.xgb.syn_id.c_index                0.860551  0.864445  0.864458
# performance.xgb.syn_id.brier_score            0.098310  0.094117  0.094879
# performance.xgb.syn_ood.c_index               0.874224  0.877785  0.875803
# performance.xgb.syn_ood.brier_score           0.096274  0.091912  0.093231
#
#                                                    min       min      Mean  \
# stats.jensenshannon_dist.marginal             0.004029  0.003817  0.004086
# stats.chi_squared_test.marginal               0.537560  0.537794  0.537978
# stats.inv_kl_divergence.marginal              0.932630  0.933125  0.936311
# stats.ks_test.marginal                        0.889190  0.890242  0.880849
# stats.max_mean_discrepancy.joint              0.000260  0.000260  0.000261
# stats.wasserstein_dist.joint                  0.018215  0.018071  0.018603
# stats.prdc.precision                          0.935840  0.937746  0.934976
# stats.prdc.recall                             0.986279  0.986787  0.983992
# stats.prdc.density                            0.833083  0.827239  0.830898
# stats.prdc.coverage                           0.919070  0.912591  0.915386
# stats.survival_km_distance.optimism           0.000188  0.000819  0.001157
# stats.survival_km_distance.abs_optimism       0.002020  0.002266  0.002317
# stats.survival_km_distance.sightedness        0.007287  0.005369  0.002531
# performance.linear_model.gt.c_index           0.864923  0.864923  0.864923
# performance.linear_model.gt.brier_score       0.086823  0.086823  0.086823
# performance.linear_model.syn_id.c_index       0.864258  0.864855  0.864446
# performance.linear_model.syn_id.brier_score   0.088434  0.088145  0.088056
# performance.linear_model.syn_ood.c_index      0.875727  0.875362  0.875158
# performance.linear_model.syn_ood.brier_score  0.087531  0.087833  0.087427
# performance.mlp.gt.c_index                    0.798863  0.798863  0.798863
# performance.mlp.gt.brier_score                0.094956  0.094956  0.094956
# performance.mlp.syn_id.c_index                0.857360  0.848358  0.850508
# performance.mlp.syn_id.brier_score            0.082804  0.087764  0.088025
# performance.mlp.syn_ood.c_index               0.859177  0.764480  0.812590
# performance.mlp.syn_ood.brier_score           0.084778  0.094416  0.095984
# performance.xgb.gt.c_index                    0.870488  0.870229  0.870403
# performance.xgb.gt.brier_score                0.094100  0.094281  0.094115
# performance.xgb.syn_id.c_index                0.863956  0.862512  0.863184
# performance.xgb.syn_id.brier_score            0.094795  0.094063  0.095233
# performance.xgb.syn_ood.c_index               0.875087  0.874075  0.875395
# performance.xgb.syn_ood.brier_score           0.093011  0.092276  0.093341
#
#                                                  Std
# stats.jensenshannon_dist.marginal             0.0003
# stats.chi_squared_test.marginal               0.0003
# stats.inv_kl_divergence.marginal              0.0036
# stats.ks_test.marginal                        0.0178
# stats.max_mean_discrepancy.joint              0.0000
# stats.wasserstein_dist.joint                  0.0013
# stats.prdc.precision                          0.0025
# stats.prdc.recall                             0.0026
# stats.prdc.density                            0.0076
# stats.prdc.coverage                           0.0038
# stats.survival_km_distance.optimism           0.0013
# stats.survival_km_distance.abs_optimism       0.0007
# stats.survival_km_distance.sightedness        0.0032
# performance.linear_model.gt.c_index           0.0000
# performance.linear_model.gt.brier_score       0.0000
# performance.linear_model.syn_id.c_index       0.0010
# performance.linear_model.syn_id.brier_score   0.0004
# performance.linear_model.syn_ood.c_index      0.0005
# performance.linear_model.syn_ood.brier_score  0.0008
# performance.mlp.gt.c_index                    0.0000
# performance.mlp.gt.brier_score                0.0000
# performance.mlp.syn_id.c_index                0.0039
# performance.mlp.syn_id.brier_score            0.0043
# performance.mlp.syn_ood.c_index               0.0393
# performance.mlp.syn_ood.brier_score           0.0065
# performance.xgb.gt.c_index                    0.0005
# performance.xgb.gt.brier_score                0.0003
# performance.xgb.syn_id.c_index                0.0015
# performance.xgb.syn_id.brier_score            0.0016
# performance.xgb.syn_ood.c_index               0.0013
# performance.xgb.syn_ood.brier_score           0.0015

# %%
p_values_df
# Out:
#             age         kappa        lambda    creatinine       sex  \
# 0  4.891011e-01  3.792380e-07  5.813786e-05  0.000000e+00  0.787067
# 1  8.631561e-19  1.463139e-19  1.524861e-10  3.229452e-22  0.149461
# 2  1.430575e-18  7.223727e-20  3.550099e-10  5.367928e-21  0.542154
# 3  8.353545e-19  1.310690e-19  2.455677e-10  2.370231e-22  0.529829
# 4  3.912599e-19  5.043870e-20  1.960701e-10  1.125723e-22  0.264611
#
#    sample.yr   flc.grp      mgus   chapter
# 0   0.766169  0.280883  1.000000  0.995529
# 1   0.555853  0.680616  1.000000  0.702513
# 2   0.279605  0.696338  0.444722  0.952673
# 3   0.290268  0.531453  0.269809  0.999321
# 4   0.341035  0.199776  0.482488  0.785948

# %% [markdown]
# # AIDS

# %%
dataset="aids"

metrics_list = []
fit_times = []
generate_times = []
p_values_list = []

for i in range(5):
    df = pd.read_csv('/content/drive/MyDrive/Datasets/aids.csv')
    df = df.drop('Unnamed: 0', axis=1)
    df = df[df['duration'] != 0]

    time = df['duration'].to_list()
    event = df['event'].to_list()

    time_event_encoded = sinusoidal_embedding(time, event, 4)
    X = df.drop(['duration', 'event'], axis=1)
    y = time_event_encoded

    syn_model = Plugins().get(plugin_name)

    # Measure the execution time of the fit function
    start = timer()
    syn_model.fit(X, cond=y)
    fit_time = timer() - start
    fit_times.append(fit_time)

    survival_df=df
    event_0_data = survival_df[survival_df['event'] == 0]['duration']
    event_1_data = survival_df[survival_df['event'] == 1]['duration']

    random_state = i + 1
    np.random.seed(random_state)

    sample_size_0 = len(event_0_data)
    sample_size_1= len(event_1_data)
    sample_event_0 = np.random.choice(event_0_data, size=sample_size_0)
    sample_event_1 = np.random.choice(event_1_data, size=sample_size_1)

    z=np.concatenate([sample_event_0,sample_event_1])
    x=np.zeros(len(sample_event_0))
    y=np.ones(len(sample_event_1))
    p=np.concatenate([x,y])

    time_event_gen_encoded=sinusoidal_embedding(z,p,4)

    # Measure the execution time of the generate function
    start = timer()
    X_gen = syn_model.generate(count=len(df), cond=np.array(time_event_gen_encoded)).dataframe()
    generate_time = timer() - start
    generate_times.append(generate_time)

    X_gen['duration'] = z
    X_gen['event'] = p
    X_gen = X_gen.sample(frac=1).reset_index(drop=True)

    # Save X_gen as a CSV file
    X_gen.to_csv(f"/content/drive/MyDrive/Nips/{dataset}_{plugin_name}_iteration_{i+1}.csv", index=False)

    loader1 = SurvivalAnalysisDataLoader(df, target_column="event", time_to_event_column="duration")
    loader2 = SurvivalAnalysisDataLoader(X_gen, target_column="event", time_to_event_column="duration")

    met_df = Metrics.evaluate(X_gt=loader1, X_syn=loader2, task_type='survival_analysis', metrics={
        'stats': ['jensenshannon_dist', 'chi_squared_test', 'feature_corr', 'inv_kl_divergence', 'ks_test',
                 'max_mean_discrepancy', 'wasserstein_dist', 'prdc', 'alpha_precision', 'survival_km_distance'],
        'performance': ['linear_model', 'mlp', 'xgb', 'feat_rank_distance']
    }, use_cache=False, random_state=random_state)

    met_df = met_df.iloc[:, 0]
    metrics_list.append(met_df)

    # Calculate p-values
    p_values_continuous, p_values_discrete = compare_distributions(df, X_gen)
    continuous_column_names = list(p_values_continuous.keys())
    discrete_column_names = list(p_values_discrete.keys())

    p_val = np.concatenate([list(p_values_continuous.values()), list(p_values_discrete.values())])
    p_values_list.append(p_val)

    workspace_dir = os.path.join(os.getcwd(), 'workspace')
    if os.path.exists(workspace_dir):
        shutil.rmtree(workspace_dir)

result_df = pd.concat(metrics_list, axis=1)

# Calculate the row-wise mean and standard deviation of the metrics
result_df['Mean'] = result_df.mean(axis=1)
result_df['Std'] = result_df.std(axis=1)
result_df['Std'] = result_df['Std'].round(4)

# Create DataFrame for p-values
p_values_df = pd.DataFrame(p_values_list, columns=continuous_column_names + discrete_column_names)

# Save result_df and p_values_df as CSV files
result_df.to_csv(f"/content/drive/MyDrive/Nips/{dataset}_{plugin_name}_result_df.csv")
p_values_df.to_csv(f"/content/drive/MyDrive/Nips/{dataset}_{plugin_name}_p_values_df.csv")

avg_fit_time = np.mean(fit_times)
avg_generate_time = np.mean(generate_times)
std_fit_time = np.std(fit_times)
std_generate_time = np.std(generate_times)

print(f"\nAverage Fit Time: {avg_fit_time:.4f} seconds, Standard Deviation: {std_fit_time:.4f} seconds")
print(f"Average Generate Time: {avg_generate_time:.4f} seconds, Standard Deviation: {std_generate_time:.4f} seconds")
# Out:
# [2024-04-13T10:55:18.138631+0000][10941][CRITICAL] module disabled: /usr/local/lib/python3.10/dist-packages/synthcity/plugins/generic/plugin_goggle.py
#   8%|▊         | 799/10000 [02:03<23:39,  6.48it/s]
# [2024-04-13T10:58:27.487368+0000][10941][CRITICAL] module disabled: /usr/local/lib/python3.10/dist-packages/synthcity/plugins/generic/plugin_goggle.py
#  13%|█▎        | 1349/10000 [03:28<22:20,  6.45it/s]
# [2024-04-13T11:02:58.858449+0000][10941][CRITICAL] module disabled: /usr/local/lib/python3.10/dist-packages/synthcity/plugins/generic/plugin_goggle.py
#  13%|█▎        | 1349/10000 [03:28<22:16,  6.47it/s]
# [2024-04-13T11:07:28.835999+0000][10941][CRITICAL] module disabled: /usr/local/lib/python3.10/dist-packages/synthcity/plugins/generic/plugin_goggle.py
#  13%|█▎        | 1349/10000 [03:30<22:26,  6.42it/s]
# [2024-04-13T11:12:04.000979+0000][10941][CRITICAL] module disabled: /usr/local/lib/python3.10/dist-packages/synthcity/plugins/generic/plugin_goggle.py
#  13%|█▎        | 1349/10000 [03:30<22:27,  6.42it/s]
# Average Fit Time: 192.6425 seconds, Standard Deviation: 34.4537 seconds
# Average Generate Time: 0.0755 seconds, Standard Deviation: 0.0117 seconds

# %%
result_df
# Out:
#                                                        min           min  \
# stats.jensenshannon_dist.marginal                 0.013653      0.005102
# stats.chi_squared_test.marginal                   0.896167      0.763337
# stats.inv_kl_divergence.marginal                  0.920458      0.954513
# stats.ks_test.marginal                            0.888325      0.950678
# stats.max_mean_discrepancy.joint                  0.001738      0.001738
# stats.wasserstein_dist.joint                  30623.065304  30296.487125
# stats.prdc.precision                              0.046916      0.033884
# stats.prdc.recall                                 0.026064      0.021720
# stats.prdc.density                                0.014944      0.017550
# stats.prdc.coverage                               0.020851      0.021720
# stats.survival_km_distance.optimism              -0.000982      0.000780
# stats.survival_km_distance.abs_optimism           0.002802      0.002720
# stats.survival_km_distance.sightedness            0.000000      0.005495
# performance.linear_model.gt.c_index               0.760921      0.760921
# performance.linear_model.gt.brier_score           0.062355      0.062355
# performance.linear_model.syn_id.c_index           0.719883      0.740564
# performance.linear_model.syn_id.brier_score       0.060877      0.060716
# performance.linear_model.syn_ood.c_index          0.818828      0.768391
# performance.linear_model.syn_ood.brier_score      0.058307      0.060572
# performance.mlp.gt.c_index                        0.725780      0.725780
# performance.mlp.gt.brier_score                    0.071506      0.071506
# performance.mlp.syn_id.c_index                    0.590396      0.714235
# performance.mlp.syn_id.brier_score                0.069169      0.064076
# performance.mlp.syn_ood.c_index                   0.547443      0.520355
# performance.mlp.syn_ood.brier_score               0.089172      0.072906
# performance.xgb.gt.c_index                        0.723639      0.727740
# performance.xgb.gt.brier_score                    0.064598      0.064634
# performance.xgb.syn_id.c_index                    0.738151      0.748594
# performance.xgb.syn_id.brier_score                0.063915      0.063960
# performance.xgb.syn_ood.c_index                   0.810821      0.721150
# performance.xgb.syn_ood.brier_score               0.061272      0.062286
#
#                                                        min           min  \
# stats.jensenshannon_dist.marginal                 0.004803      0.004898
# stats.chi_squared_test.marginal                   0.764112      0.763607
# stats.inv_kl_divergence.marginal                  0.964672      0.954898
# stats.ks_test.marginal                            0.951748      0.951413
# stats.max_mean_discrepancy.joint                  0.001738      0.001738
# stats.wasserstein_dist.joint                  29862.941744  29804.092424
# stats.prdc.precision                              0.042572      0.035621
# stats.prdc.recall                                 0.023458      0.026064
# stats.prdc.density                                0.018766      0.018766
# stats.prdc.coverage                               0.019983      0.022589
# stats.survival_km_distance.optimism              -0.001942     -0.001944
# stats.survival_km_distance.abs_optimism           0.003150      0.003266
# stats.survival_km_distance.sightedness            0.000000      0.000000
# performance.linear_model.gt.c_index               0.760921      0.760921
# performance.linear_model.gt.brier_score           0.062355      0.062355
# performance.linear_model.syn_id.c_index           0.758155      0.750516
# performance.linear_model.syn_id.brier_score       0.060703      0.060877
# performance.linear_model.syn_ood.c_index          0.793161      0.806412
# performance.linear_model.syn_ood.brier_score      0.059652      0.059664
# performance.mlp.gt.c_index                        0.725780      0.725780
# performance.mlp.gt.brier_score                    0.071506      0.071506
# performance.mlp.syn_id.c_index                    0.698828      0.715748
# performance.mlp.syn_id.brier_score                0.064133      0.065425
# performance.mlp.syn_ood.c_index                   0.631427      0.545759
# performance.mlp.syn_ood.brier_score               0.063316      0.063876
# performance.xgb.gt.c_index                        0.717010      0.717547
# performance.xgb.gt.brier_score                    0.064619      0.064591
# performance.xgb.syn_id.c_index                    0.737320      0.745446
# performance.xgb.syn_id.brier_score                0.063634      0.063754
# performance.xgb.syn_ood.c_index                   0.707487      0.743584
# performance.xgb.syn_ood.brier_score               0.062242      0.062111
#
#                                                        min          Mean  \
# stats.jensenshannon_dist.marginal                 0.004771      0.006646
# stats.chi_squared_test.marginal                   0.765464      0.790537
# stats.inv_kl_divergence.marginal                  0.954389      0.949786
# stats.ks_test.marginal                            0.951614      0.938756
# stats.max_mean_discrepancy.joint                  0.001738      0.001738
# stats.wasserstein_dist.joint                  30988.264770  30314.970273
# stats.prdc.precision                              0.033884      0.038575
# stats.prdc.recall                                 0.023458      0.024153
# stats.prdc.density                                0.014944      0.016994
# stats.prdc.coverage                               0.021720      0.021373
# stats.survival_km_distance.optimism              -0.000794     -0.000976
# stats.survival_km_distance.abs_optimism           0.002435      0.002874
# stats.survival_km_distance.sightedness            0.000000      0.001099
# performance.linear_model.gt.c_index               0.760921      0.760921
# performance.linear_model.gt.brier_score           0.062355      0.062355
# performance.linear_model.syn_id.c_index           0.748276      0.743479
# performance.linear_model.syn_id.brier_score       0.060639      0.060762
# performance.linear_model.syn_ood.c_index          0.801990      0.797757
# performance.linear_model.syn_ood.brier_score      0.059365      0.059512
# performance.mlp.gt.c_index                        0.725780      0.725780
# performance.mlp.gt.brier_score                    0.071506      0.071506
# performance.mlp.syn_id.c_index                    0.737613      0.691364
# performance.mlp.syn_id.brier_score                0.070163      0.066593
# performance.mlp.syn_ood.c_index                   0.629928      0.574983
# performance.mlp.syn_ood.brier_score               0.065085      0.070871
# performance.xgb.gt.c_index                        0.723610      0.721909
# performance.xgb.gt.brier_score                    0.064625      0.064614
# performance.xgb.syn_id.c_index                    0.722811      0.738464
# performance.xgb.syn_id.brier_score                0.064070      0.063867
# performance.xgb.syn_ood.c_index                   0.740791      0.744767
# performance.xgb.syn_ood.brier_score               0.062211      0.062025
#
#                                                    Std
# stats.jensenshannon_dist.marginal               0.0035
# stats.chi_squared_test.marginal                 0.0528
# stats.inv_kl_divergence.marginal                0.0152
# stats.ks_test.marginal                          0.0252
# stats.max_mean_discrepancy.joint                0.0000
# stats.wasserstein_dist.joint                  450.3145
# stats.prdc.precision                            0.0053
# stats.prdc.recall                               0.0017
# stats.prdc.density                              0.0017
# stats.prdc.coverage                             0.0009
# stats.survival_km_distance.optimism             0.0010
# stats.survival_km_distance.abs_optimism         0.0003
# stats.survival_km_distance.sightedness          0.0022
# performance.linear_model.gt.c_index             0.0000
# performance.linear_model.gt.brier_score         0.0000
# performance.linear_model.syn_id.c_index         0.0131
# performance.linear_model.syn_id.brier_score     0.0001
# performance.linear_model.syn_ood.c_index        0.0169
# performance.linear_model.syn_ood.brier_score    0.0007
# performance.mlp.gt.c_index                      0.0000
# performance.mlp.gt.brier_score                  0.0000
# performance.mlp.syn_id.c_index                  0.0520
# performance.mlp.syn_id.brier_score              0.0026
# performance.mlp.syn_ood.c_index                 0.0465
# performance.mlp.syn_ood.brier_score             0.0098
# performance.xgb.gt.c_index                      0.0041
# performance.xgb.gt.brier_score                  0.0000
# performance.xgb.syn_id.c_index                  0.0089
# performance.xgb.syn_id.brier_score              0.0002
# performance.xgb.syn_ood.c_index                 0.0356
# performance.xgb.syn_ood.brier_score             0.0004

# %%
p_values_df
# Out:
#             age           cd4      priorzdv  hemophil    ivdrug    karnof  \
# 0  2.342176e-50  1.093345e-33  1.061062e-28  1.000000  0.091138  0.757849
# 1  6.065534e-17  2.285822e-02  3.991644e-12  0.079760  0.805572  0.824252
# 2  4.157416e-16  2.950714e-02  2.119103e-11  1.000000  0.279162  0.136999
# 3  1.962862e-16  3.689727e-02  2.710320e-12  0.986282  0.811510  0.935954
# 4  1.917176e-16  1.712946e-02  3.930109e-12  0.453138  0.731768  0.188995
#
#      raceth       sex    strat2        tx     txgrp
# 0  0.090484  0.555921  0.810878  0.001600  0.138806
# 1  0.334753  0.802355  0.309324  0.617674  0.811564
# 2  0.618646  0.955710  0.297512  0.658882  0.568105
# 3  0.000420  0.548220  0.540078  0.302412  0.530971
# 4  0.652758  0.130194  1.000000  0.461682  0.725945

# %% [markdown]
# # Metabric

# %%
dataset="metabric"

metrics_list = []
fit_times = []
generate_times = []
p_values_list = []

for i in range(5):
    df = datasets.metabric.read_df()
    df = df[df['duration'] != 0]

    time = df['duration'].to_list()
    event = df['event'].to_list()

    time_event_encoded = sinusoidal_embedding(time, event, 4)
    X = df.drop(['duration', 'event'], axis=1)
    y = time_event_encoded

    syn_model = Plugins().get(plugin_name)

    # Measure the execution time of the fit function
    start = timer()
    syn_model.fit(X, cond=y)
    fit_time = timer() - start
    fit_times.append(fit_time)

    survival_df=df
    event_0_data = survival_df[survival_df['event'] == 0]['duration']
    event_1_data = survival_df[survival_df['event'] == 1]['duration']

    random_state = i + 1
    np.random.seed(random_state)

    sample_size_0 = len(event_0_data)
    sample_size_1= len(event_1_data)
    sample_event_0 = np.random.choice(event_0_data, size=sample_size_0)
    sample_event_1 = np.random.choice(event_1_data, size=sample_size_1)

    z=np.concatenate([sample_event_0,sample_event_1])
    x=np.zeros(len(sample_event_0))
    y=np.ones(len(sample_event_1))
    p=np.concatenate([x,y])

    time_event_gen_encoded=sinusoidal_embedding(z,p,4)

    # Measure the execution time of the generate function
    start = timer()
    X_gen = syn_model.generate(count=len(df), cond=np.array(time_event_gen_encoded)).dataframe()
    generate_time = timer() - start
    generate_times.append(generate_time)

    X_gen['duration'] = z
    X_gen['event'] = p
    X_gen = X_gen.sample(frac=1).reset_index(drop=True)

    # Save X_gen as a CSV file
    X_gen.to_csv(f"/content/drive/MyDrive/Nips/{dataset}_{plugin_name}_iteration_{i+1}.csv", index=False)

    loader1 = SurvivalAnalysisDataLoader(df, target_column="event", time_to_event_column="duration")
    loader2 = SurvivalAnalysisDataLoader(X_gen, target_column="event", time_to_event_column="duration")

    met_df = Metrics.evaluate(X_gt=loader1, X_syn=loader2, task_type='survival_analysis', metrics={
        'stats': ['jensenshannon_dist', 'chi_squared_test', 'feature_corr', 'inv_kl_divergence', 'ks_test',
                 'max_mean_discrepancy', 'wasserstein_dist', 'prdc', 'alpha_precision', 'survival_km_distance'],
        'performance': ['linear_model', 'mlp', 'xgb', 'feat_rank_distance']
    }, use_cache=False, random_state=random_state)

    met_df = met_df.iloc[:, 0]
    metrics_list.append(met_df)

    # Calculate p-values
    p_values_continuous, p_values_discrete = compare_distributions(df, X_gen)
    continuous_column_names = list(p_values_continuous.keys())
    discrete_column_names = list(p_values_discrete.keys())

    p_val = np.concatenate([list(p_values_continuous.values()), list(p_values_discrete.values())])
    p_values_list.append(p_val)

    workspace_dir = os.path.join(os.getcwd(), 'workspace')
    if os.path.exists(workspace_dir):
        shutil.rmtree(workspace_dir)

result_df = pd.concat(metrics_list, axis=1)

# Calculate the row-wise mean and standard deviation of the metrics
result_df['Mean'] = result_df.mean(axis=1)
result_df['Std'] = result_df.std(axis=1)
result_df['Std'] = result_df['Std'].round(4)

# Create DataFrame for p-values
p_values_df = pd.DataFrame(p_values_list, columns=continuous_column_names + discrete_column_names)

# Save result_df and p_values_df as CSV files
result_df.to_csv(f"/content/drive/MyDrive/Nips/{dataset}_{plugin_name}_result_df.csv")
p_values_df.to_csv(f"/content/drive/MyDrive/Nips/{dataset}_{plugin_name}_p_values_df.csv")

avg_fit_time = np.mean(fit_times)
avg_generate_time = np.mean(generate_times)
std_fit_time = np.std(fit_times)
std_generate_time = np.std(generate_times)

print(f"\nAverage Fit Time: {avg_fit_time:.4f} seconds, Standard Deviation: {std_fit_time:.4f} seconds")
print(f"Average Generate Time: {avg_generate_time:.4f} seconds, Standard Deviation: {std_generate_time:.4f} seconds")
# Out:
# [2024-04-13T11:16:35.993650+0000][10941][CRITICAL] module disabled: /usr/local/lib/python3.10/dist-packages/synthcity/plugins/generic/plugin_goggle.py
#   5%|▍         | 499/10000 [01:59<37:47,  4.19it/s]
# [2024-04-13T11:20:20.957092+0000][10941][CRITICAL] module disabled: /usr/local/lib/python3.10/dist-packages/synthcity/plugins/generic/plugin_goggle.py
#   5%|▍         | 499/10000 [01:57<37:17,  4.25it/s]
# [2024-04-13T11:24:03.347230+0000][10941][CRITICAL] module disabled: /usr/local/lib/python3.10/dist-packages/synthcity/plugins/generic/plugin_goggle.py
#   5%|▍         | 499/10000 [01:58<37:43,  4.20it/s]
# [2024-04-13T11:27:47.033401+0000][10941][CRITICAL] module disabled: /usr/local/lib/python3.10/dist-packages/synthcity/plugins/generic/plugin_goggle.py
#   5%|▍         | 499/10000 [01:57<37:15,  4.25it/s]
# [2024-04-13T11:31:28.501165+0000][10941][CRITICAL] module disabled: /usr/local/lib/python3.10/dist-packages/synthcity/plugins/generic/plugin_goggle.py
#   5%|▍         | 499/10000 [01:57<37:18,  4.25it/s]
# Average Fit Time: 119.6635 seconds, Standard Deviation: 1.1724 seconds
# Average Generate Time: 0.0848 seconds, Standard Deviation: 0.0169 seconds

# %%
result_df
# Out:
#                                                    min       min       min  \
# stats.jensenshannon_dist.marginal             0.009024  0.009400  0.009486
# stats.chi_squared_test.marginal               0.528164  0.526284  0.527028
# stats.inv_kl_divergence.marginal              0.901807  0.919840  0.900446
# stats.ks_test.marginal                        0.911241  0.909473  0.908613
# stats.max_mean_discrepancy.joint              0.001058  0.001058  0.001057
# stats.wasserstein_dist.joint                  0.037183  0.038140  0.037313
# stats.prdc.precision                          0.982133  0.973200  0.980032
# stats.prdc.recall                             0.955334  0.950079  0.955859
# stats.prdc.density                            1.034157  1.020179  1.023752
# stats.prdc.coverage                           0.937467  0.938518  0.944298
# stats.survival_km_distance.optimism           0.002058  0.000212  0.009468
# stats.survival_km_distance.abs_optimism       0.006651  0.004364  0.016303
# stats.survival_km_distance.sightedness        0.000000  0.000000  0.000000
# performance.linear_model.gt.c_index           0.630465  0.630465  0.630465
# performance.linear_model.gt.brier_score       0.189282  0.189282  0.189282
# performance.linear_model.syn_id.c_index       0.621633  0.623828  0.617994
# performance.linear_model.syn_id.brier_score   0.193093  0.192624  0.194042
# performance.linear_model.syn_ood.c_index      0.623803  0.628944  0.621591
# performance.linear_model.syn_ood.brier_score  0.198526  0.196859  0.198297
# performance.mlp.gt.c_index                    0.541779  0.541779  0.541779
# performance.mlp.gt.brier_score                0.213681  0.213681  0.213681
# performance.mlp.syn_id.c_index                0.585326  0.586452  0.584567
# performance.mlp.syn_id.brier_score            0.210181  0.210996  0.209322
# performance.mlp.syn_ood.c_index               0.584760  0.587470  0.579573
# performance.mlp.syn_ood.brier_score           0.215965  0.217827  0.209801
# performance.xgb.gt.c_index                    0.636638  0.636959  0.636790
# performance.xgb.gt.brier_score                0.200157  0.200245  0.200107
# performance.xgb.syn_id.c_index                0.619538  0.606670  0.611856
# performance.xgb.syn_id.brier_score            0.201543  0.202922  0.201200
# performance.xgb.syn_ood.c_index               0.614858  0.600404  0.610703
# performance.xgb.syn_ood.brier_score           0.206648  0.208587  0.206335
#
#                                                    min       min      Mean  \
# stats.jensenshannon_dist.marginal             0.009408  0.009216  0.009307
# stats.chi_squared_test.marginal               0.526889  0.527668  0.527206
# stats.inv_kl_divergence.marginal              0.900940  0.901215  0.904850
# stats.ks_test.marginal                        0.909903  0.909760  0.909798
# stats.max_mean_discrepancy.joint              0.001057  0.001055  0.001057
# stats.wasserstein_dist.joint                  0.039089  0.035725  0.037490
# stats.prdc.precision                          0.977404  0.974777  0.977509
# stats.prdc.recall                             0.953757  0.951655  0.953337
# stats.prdc.density                            1.023121  1.038045  1.027851
# stats.prdc.coverage                           0.932738  0.944824  0.939569
# stats.survival_km_distance.optimism          -0.002724 -0.007387  0.000326
# stats.survival_km_distance.abs_optimism       0.007308  0.010341  0.008993
# stats.survival_km_distance.sightedness        0.000000  0.000000  0.000000
# performance.linear_model.gt.c_index           0.630465  0.630465  0.630465
# performance.linear_model.gt.brier_score       0.189282  0.189282  0.189282
# performance.linear_model.syn_id.c_index       0.625072  0.620803  0.621866
# performance.linear_model.syn_id.brier_score   0.192792  0.192709  0.193052
# performance.linear_model.syn_ood.c_index      0.627260  0.627615  0.625842
# performance.linear_model.syn_ood.brier_score  0.197095  0.197175  0.197590
# performance.mlp.gt.c_index                    0.541779  0.541779  0.541779
# performance.mlp.gt.brier_score                0.213681  0.213681  0.213681
# performance.mlp.syn_id.c_index                0.585086  0.593639  0.587014
# performance.mlp.syn_id.brier_score            0.206400  0.211997  0.209779
# performance.mlp.syn_ood.c_index               0.582679  0.585195  0.583935
# performance.mlp.syn_ood.brier_score           0.216129  0.215873  0.215119
# performance.xgb.gt.c_index                    0.635815  0.636592  0.636559
# performance.xgb.gt.brier_score                0.200242  0.200131  0.200176
# performance.xgb.syn_id.c_index                0.618969  0.608663  0.613140
# performance.xgb.syn_id.brier_score            0.202054  0.202448  0.202033
# performance.xgb.syn_ood.c_index               0.618254  0.618948  0.612633
# performance.xgb.syn_ood.brier_score           0.206684  0.206030  0.206857
#
#                                                  Std
# stats.jensenshannon_dist.marginal             0.0002
# stats.chi_squared_test.marginal               0.0007
# stats.inv_kl_divergence.marginal              0.0075
# stats.ks_test.marginal                        0.0008
# stats.max_mean_discrepancy.joint              0.0000
# stats.wasserstein_dist.joint                  0.0011
# stats.prdc.precision                          0.0033
# stats.prdc.recall                             0.0022
# stats.prdc.density                            0.0070
# stats.prdc.coverage                           0.0045
# stats.survival_km_distance.optimism           0.0056
# stats.survival_km_distance.abs_optimism       0.0041
# stats.survival_km_distance.sightedness        0.0000
# performance.linear_model.gt.c_index           0.0000
# performance.linear_model.gt.brier_score       0.0000
# performance.linear_model.syn_id.c_index       0.0025
# performance.linear_model.syn_id.brier_score   0.0005
# performance.linear_model.syn_ood.c_index      0.0027
# performance.linear_model.syn_ood.brier_score  0.0007
# performance.mlp.gt.c_index                    0.0000
# performance.mlp.gt.brier_score                0.0000
# performance.mlp.syn_id.c_index                0.0034
# performance.mlp.syn_id.brier_score            0.0019
# performance.mlp.syn_ood.c_index               0.0027
# performance.mlp.syn_ood.brier_score           0.0028
# performance.xgb.gt.c_index                    0.0004
# performance.xgb.gt.brier_score                0.0001
# performance.xgb.syn_id.c_index                0.0053
# performance.xgb.syn_id.brier_score            0.0006
# performance.xgb.syn_ood.c_index               0.0068
# performance.xgb.syn_ood.brier_score           0.0009

# %%
p_values_df
# Out:
#              x0            x1            x2            x3        x8        x4  \
# 0  5.026350e-21  4.152874e-28  4.480720e-59  6.812081e-07  0.002581  0.014348
# 1  5.284639e-22  1.563838e-28  1.329606e-61  9.280435e-07  0.003900  0.605140
# 2  2.858818e-23  2.792157e-27  5.843211e-59  2.456029e-07  0.002919  0.312167
# 3  7.748153e-23  8.527337e-29  6.511547e-60  1.364957e-07  0.006737  0.457226
# 4  5.427032e-22  7.772052e-29  1.984114e-61  1.155903e-07  0.001746  0.451331
#
#          x5        x6        x7
# 0  0.414211  0.069509  0.679073
# 1  0.520481  0.321161  0.216240
# 2  0.341493  0.550498  0.200267
# 3  0.751086  0.477849  0.880831
# 4  0.516995  0.481445  0.075868

# %% [markdown]
# # GBSG

# %%
dataset="gbsg"

metrics_list = []
fit_times = []
generate_times = []
p_values_list = []

for i in range(5):
    df = datasets.gbsg.read_df()
    df = df[df['duration'] != 0]

    time = df['duration'].to_list()
    event = df['event'].to_list()

    time_event_encoded = sinusoidal_embedding(time, event, 4)
    X = df.drop(['duration', 'event'], axis=1)
    y = time_event_encoded

    syn_model = Plugins().get(plugin_name)

    # Measure the execution time of the fit function
    start = timer()
    syn_model.fit(X, cond=y)
    fit_time = timer() - start
    fit_times.append(fit_time)

    survival_df=df
    event_0_data = survival_df[survival_df['event'] == 0]['duration']
    event_1_data = survival_df[survival_df['event'] == 1]['duration']

    random_state = i + 1
    np.random.seed(random_state)

    sample_size_0 = len(event_0_data)
    sample_size_1= len(event_1_data)
    sample_event_0 = np.random.choice(event_0_data, size=sample_size_0)
    sample_event_1 = np.random.choice(event_1_data, size=sample_size_1)

    z=np.concatenate([sample_event_0,sample_event_1])
    x=np.zeros(len(sample_event_0))
    y=np.ones(len(sample_event_1))
    p=np.concatenate([x,y])

    time_event_gen_encoded=sinusoidal_embedding(z,p,4)

    # Measure the execution time of the generate function
    start = timer()
    X_gen = syn_model.generate(count=len(df), cond=np.array(time_event_gen_encoded)).dataframe()
    generate_time = timer() - start
    generate_times.append(generate_time)

    X_gen['duration'] = z
    X_gen['event'] = p
    X_gen = X_gen.sample(frac=1).reset_index(drop=True)

    # Save X_gen as a CSV file
    X_gen.to_csv(f"/content/drive/MyDrive/Nips/{dataset}_{plugin_name}_iteration_{i+1}.csv", index=False)

    loader1 = SurvivalAnalysisDataLoader(df, target_column="event", time_to_event_column="duration")
    loader2 = SurvivalAnalysisDataLoader(X_gen, target_column="event", time_to_event_column="duration")

    met_df = Metrics.evaluate(X_gt=loader1, X_syn=loader2, task_type='survival_analysis', metrics={
        'stats': ['jensenshannon_dist', 'chi_squared_test', 'feature_corr', 'inv_kl_divergence', 'ks_test',
                 'max_mean_discrepancy', 'wasserstein_dist', 'prdc', 'alpha_precision', 'survival_km_distance'],
        'performance': ['linear_model', 'mlp', 'xgb', 'feat_rank_distance']
    }, use_cache=False, random_state=random_state)

    met_df = met_df.iloc[:, 0]
    metrics_list.append(met_df)

    # Calculate p-values
    p_values_continuous, p_values_discrete = compare_distributions(df, X_gen)
    continuous_column_names = list(p_values_continuous.keys())
    discrete_column_names = list(p_values_discrete.keys())

    p_val = np.concatenate([list(p_values_continuous.values()), list(p_values_discrete.values())])
    p_values_list.append(p_val)

    workspace_dir = os.path.join(os.getcwd(), 'workspace')
    if os.path.exists(workspace_dir):
        shutil.rmtree(workspace_dir)

result_df = pd.concat(metrics_list, axis=1)

# Calculate the row-wise mean and standard deviation of the metrics
result_df['Mean'] = result_df.mean(axis=1)
result_df['Std'] = result_df.std(axis=1)
result_df['Std'] = result_df['Std'].round(4)

# Create DataFrame for p-values
p_values_df = pd.DataFrame(p_values_list, columns=continuous_column_names + discrete_column_names)

# Save result_df and p_values_df as CSV files
result_df.to_csv(f"/content/drive/MyDrive/Nips/{dataset}_{plugin_name}_result_df.csv")
p_values_df.to_csv(f"/content/drive/MyDrive/Nips/{dataset}_{plugin_name}_p_values_df.csv")

avg_fit_time = np.mean(fit_times)
avg_generate_time = np.mean(generate_times)
std_fit_time = np.std(fit_times)
std_generate_time = np.std(generate_times)

print(f"\nAverage Fit Time: {avg_fit_time:.4f} seconds, Standard Deviation: {std_fit_time:.4f} seconds")
print(f"Average Generate Time: {avg_generate_time:.4f} seconds, Standard Deviation: {std_generate_time:.4f} seconds")
# Out:
# Dataset 'gbsg' not locally available. Downloading...
# [2024-04-13T11:35:10.541460+0000][10941][CRITICAL] module disabled: /usr/local/lib/python3.10/dist-packages/synthcity/plugins/generic/plugin_goggle.py
# Done
#   8%|▊         | 799/10000 [03:24<39:11,  3.91it/s]
# [2024-04-13T11:40:35.986062+0000][10941][CRITICAL] module disabled: /usr/local/lib/python3.10/dist-packages/synthcity/plugins/generic/plugin_goggle.py
#   8%|▊         | 799/10000 [03:24<39:18,  3.90it/s]
# [2024-04-13T11:46:01.323412+0000][10941][CRITICAL] module disabled: /usr/local/lib/python3.10/dist-packages/synthcity/plugins/generic/plugin_goggle.py
#   8%|▊         | 799/10000 [03:23<39:06,  3.92it/s]
# [2024-04-13T11:51:27.839683+0000][10941][CRITICAL] module disabled: /usr/local/lib/python3.10/dist-packages/synthcity/plugins/generic/plugin_goggle.py
#   8%|▊         | 799/10000 [03:24<39:12,  3.91it/s]
# [2024-04-13T11:56:54.208536+0000][10941][CRITICAL] module disabled: /usr/local/lib/python3.10/dist-packages/synthcity/plugins/generic/plugin_goggle.py
#   8%|▊         | 799/10000 [03:18<38:09,  4.02it/s]
# Average Fit Time: 204.5699 seconds, Standard Deviation: 2.3434 seconds
# Average Generate Time: 0.0656 seconds, Standard Deviation: 0.0021 seconds

# %%
result_df
# Out:
#                                                    min       min       min  \
# stats.jensenshannon_dist.marginal             0.004535  0.004268  0.004853
# stats.chi_squared_test.marginal               0.547532  0.548162  0.545348
# stats.inv_kl_divergence.marginal              0.970671  0.968456  0.968307
# stats.ks_test.marginal                        0.918807  0.920002  0.915771
# stats.max_mean_discrepancy.joint              0.000898  0.000898  0.000899
# stats.wasserstein_dist.joint                  0.012268  0.011344  0.012269
# stats.prdc.precision                          0.987455  0.990143  0.985663
# stats.prdc.recall                             0.935484  0.935484  0.928763
# stats.prdc.density                            0.972760  0.981989  0.970609
# stats.prdc.coverage                           0.806900  0.806004  0.793907
# stats.survival_km_distance.optimism           0.005798  0.000267  0.000599
# stats.survival_km_distance.abs_optimism       0.007002  0.004096  0.004229
# stats.survival_km_distance.sightedness        0.017676  0.000000  0.000000
# performance.linear_model.gt.c_index           0.678109  0.678109  0.678109
# performance.linear_model.gt.brier_score       0.204760  0.204760  0.204760
# performance.linear_model.syn_id.c_index       0.648025  0.658696  0.656291
# performance.linear_model.syn_id.brier_score   0.214912  0.212461  0.212392
# performance.linear_model.syn_ood.c_index      0.655153  0.662861  0.655909
# performance.linear_model.syn_ood.brier_score  0.209808  0.208710  0.208716
# performance.mlp.gt.c_index                    0.575017  0.575017  0.575017
# performance.mlp.gt.brier_score                0.238290  0.238290  0.238290
# performance.mlp.syn_id.c_index                0.596662  0.597926  0.559043
# performance.mlp.syn_id.brier_score            0.226121  0.226216  0.231742
# performance.mlp.syn_ood.c_index               0.569718  0.514920  0.541204
# performance.mlp.syn_ood.brier_score           0.227037  0.232300  0.239192
# performance.xgb.gt.c_index                    0.695324  0.695443  0.694734
# performance.xgb.gt.brier_score                0.205717  0.205379  0.205685
# performance.xgb.syn_id.c_index                0.679307  0.688960  0.696201
# performance.xgb.syn_id.brier_score            0.215256  0.214216  0.211501
# performance.xgb.syn_ood.c_index               0.682114  0.681110  0.677763
# performance.xgb.syn_ood.brier_score           0.214282  0.214752  0.213658
#
#                                                    min       min      Mean  \
# stats.jensenshannon_dist.marginal             0.004887  0.005041  0.004717
# stats.chi_squared_test.marginal               0.545230  0.545562  0.546367
# stats.inv_kl_divergence.marginal              0.968866  0.968547  0.968969
# stats.ks_test.marginal                        0.915074  0.916219  0.917174
# stats.max_mean_discrepancy.joint              0.000899  0.000898  0.000898
# stats.wasserstein_dist.joint                  0.013077  0.012810  0.012354
# stats.prdc.precision                          0.985215  0.988351  0.987366
# stats.prdc.recall                             0.948477  0.926075  0.934857
# stats.prdc.density                            0.960484  0.965950  0.970358
# stats.prdc.coverage                           0.806900  0.802867  0.803315
# stats.survival_km_distance.optimism           0.003177  0.006264  0.003221
# stats.survival_km_distance.abs_optimism       0.004144  0.006720  0.005238
# stats.survival_km_distance.sightedness        0.036104  0.000000  0.010756
# performance.linear_model.gt.c_index           0.678109  0.678109  0.678109
# performance.linear_model.gt.brier_score       0.204760  0.204760  0.204760
# performance.linear_model.syn_id.c_index       0.656771  0.652856  0.654528
# performance.linear_model.syn_id.brier_score   0.212521  0.213713  0.213200
# performance.linear_model.syn_ood.c_index      0.656562  0.655070  0.657111
# performance.linear_model.syn_ood.brier_score  0.209300  0.209351  0.209177
# performance.mlp.gt.c_index                    0.575017  0.575017  0.575017
# performance.mlp.gt.brier_score                0.238290  0.238290  0.238290
# performance.mlp.syn_id.c_index                0.593196  0.469159  0.563197
# performance.mlp.syn_id.brier_score            0.230146  0.239383  0.230722
# performance.mlp.syn_ood.c_index               0.500083  0.500000  0.525185
# performance.mlp.syn_ood.brier_score           0.233711  0.230663  0.232580
# performance.xgb.gt.c_index                    0.695615  0.694891  0.695201
# performance.xgb.gt.brier_score                0.205547  0.205396  0.205545
# performance.xgb.syn_id.c_index                0.686774  0.693405  0.688929
# performance.xgb.syn_id.brier_score            0.212531  0.210707  0.212842
# performance.xgb.syn_ood.c_index               0.679052  0.676771  0.679362
# performance.xgb.syn_ood.brier_score           0.213256  0.212287  0.213647
#
#                                                  Std
# stats.jensenshannon_dist.marginal             0.0003
# stats.chi_squared_test.marginal               0.0012
# stats.inv_kl_divergence.marginal              0.0009
# stats.ks_test.marginal                        0.0019
# stats.max_mean_discrepancy.joint              0.0000
# stats.wasserstein_dist.joint                  0.0006
# stats.prdc.precision                          0.0018
# stats.prdc.recall                             0.0078
# stats.prdc.density                            0.0072
# stats.prdc.coverage                           0.0049
# stats.survival_km_distance.optimism           0.0025
# stats.survival_km_distance.abs_optimism       0.0013
# stats.survival_km_distance.sightedness        0.0144
# performance.linear_model.gt.c_index           0.0000
# performance.linear_model.gt.brier_score       0.0000
# performance.linear_model.syn_id.c_index       0.0038
# performance.linear_model.syn_id.brier_score   0.0010
# performance.linear_model.syn_ood.c_index      0.0029
# performance.linear_model.syn_ood.brier_score  0.0004
# performance.mlp.gt.c_index                    0.0000
# performance.mlp.gt.brier_score                0.0000
# performance.mlp.syn_id.c_index                0.0492
# performance.mlp.syn_id.brier_score            0.0049
# performance.mlp.syn_ood.c_index               0.0269
# performance.mlp.syn_ood.brier_score           0.0040
# performance.xgb.gt.c_index                    0.0003
# performance.xgb.gt.brier_score                0.0001
# performance.xgb.syn_id.c_index                0.0058
# performance.xgb.syn_id.brier_score            0.0017
# performance.xgb.syn_ood.c_index               0.0020
# performance.xgb.syn_ood.brier_score           0.0009

# %%
p_values_df
# Out:
#              x3            x4        x5        x6        x0        x1  \
# 0  2.657228e-18  3.220611e-11  0.371267  0.000201  0.948878  0.190918
# 1  3.574633e-17  1.966961e-12  0.251958  0.000027  0.473448  0.226338
# 2  9.016398e-20  7.138194e-10  0.064474  0.000700  0.892067  0.927489
# 3  9.322572e-22  1.214655e-09  0.045201  0.001576  0.670486  0.033556
# 4  1.509337e-20  3.690529e-10  0.279565  0.000800  1.000000  0.242953
#
#          x2
# 0  0.628832
# 1  0.537244
# 2  0.921723
# 3  1.000000
# 4  0.233955

# %% [markdown]
# # SUPPORT

# %%
dataset="support"

metrics_list = []
fit_times = []
generate_times = []
p_values_list = []

for i in range(5):
    df = datasets.support.read_df()
    df = df[df['duration'] != 0]

    time = df['duration'].to_list()
    event = df['event'].to_list()

    time_event_encoded = sinusoidal_embedding(time, event, 4)
    X = df.drop(['duration', 'event'], axis=1)
    y = time_event_encoded

    syn_model = Plugins().get(plugin_name)

    # Measure the execution time of the fit function
    start = timer()
    syn_model.fit(X, cond=y)
    fit_time = timer() - start
    fit_times.append(fit_time)

    survival_df=df
    event_0_data = survival_df[survival_df['event'] == 0]['duration']
    event_1_data = survival_df[survival_df['event'] == 1]['duration']

    random_state = i + 1
    np.random.seed(random_state)

    sample_size_0 = len(event_0_data)
    sample_size_1= len(event_1_data)
    sample_event_0 = np.random.choice(event_0_data, size=sample_size_0)
    sample_event_1 = np.random.choice(event_1_data, size=sample_size_1)

    z=np.concatenate([sample_event_0,sample_event_1])
    x=np.zeros(len(sample_event_0))
    y=np.ones(len(sample_event_1))
    p=np.concatenate([x,y])

    time_event_gen_encoded=sinusoidal_embedding(z,p,4)

    # Measure the execution time of the generate function
    start = timer()
    X_gen = syn_model.generate(count=len(df), cond=np.array(time_event_gen_encoded)).dataframe()
    generate_time = timer() - start
    generate_times.append(generate_time)

    X_gen['duration'] = z
    X_gen['event'] = p
    X_gen = X_gen.sample(frac=1).reset_index(drop=True)

    # Save X_gen as a CSV file
    X_gen.to_csv(f"/content/drive/MyDrive/Nips/{dataset}_{plugin_name}_iteration_{i+1}.csv", index=False)

    loader1 = SurvivalAnalysisDataLoader(df, target_column="event", time_to_event_column="duration")
    loader2 = SurvivalAnalysisDataLoader(X_gen, target_column="event", time_to_event_column="duration")

    met_df = Metrics.evaluate(X_gt=loader1, X_syn=loader2, task_type='survival_analysis', metrics={
        'stats': ['jensenshannon_dist', 'chi_squared_test', 'feature_corr', 'inv_kl_divergence', 'ks_test',
                 'max_mean_discrepancy', 'wasserstein_dist', 'prdc', 'alpha_precision', 'survival_km_distance'],
        'performance': ['linear_model', 'mlp', 'xgb', 'feat_rank_distance']
    }, use_cache=False, random_state=random_state)

    met_df = met_df.iloc[:, 0]
    metrics_list.append(met_df)

    # Calculate p-values
    p_values_continuous, p_values_discrete = compare_distributions(df, X_gen)
    continuous_column_names = list(p_values_continuous.keys())
    discrete_column_names = list(p_values_discrete.keys())

    p_val = np.concatenate([list(p_values_continuous.values()), list(p_values_discrete.values())])
    p_values_list.append(p_val)

    workspace_dir = os.path.join(os.getcwd(), 'workspace')
    if os.path.exists(workspace_dir):
        shutil.rmtree(workspace_dir)

result_df = pd.concat(metrics_list, axis=1)

# Calculate the row-wise mean and standard deviation of the metrics
result_df['Mean'] = result_df.mean(axis=1)
result_df['Std'] = result_df.std(axis=1)
result_df['Std'] = result_df['Std'].round(4)

# Create DataFrame for p-values
p_values_df = pd.DataFrame(p_values_list, columns=continuous_column_names + discrete_column_names)

# Save result_df and p_values_df as CSV files
result_df.to_csv(f"/content/drive/MyDrive/Nips/{dataset}_{plugin_name}_result_df.csv")
p_values_df.to_csv(f"/content/drive/MyDrive/Nips/{dataset}_{plugin_name}_p_values_df.csv")

avg_fit_time = np.mean(fit_times)
avg_generate_time = np.mean(generate_times)
std_fit_time = np.std(fit_times)
std_generate_time = np.std(generate_times)

print(f"\nAverage Fit Time: {avg_fit_time:.4f} seconds, Standard Deviation: {std_fit_time:.4f} seconds")
print(f"Average Generate Time: {avg_generate_time:.4f} seconds, Standard Deviation: {std_generate_time:.4f} seconds")
# Out:
# [2024-04-13T19:59:01.838541+0000][2455][CRITICAL] module disabled: /usr/local/lib/python3.10/dist-packages/synthcity/plugins/generic/plugin_goggle.py
#   4%|▍         | 449/10000 [08:27<3:00:04,  1.13s/it]
# [KeOps] Generating code for Max_SumShiftExpWeight_Reduction reduction (with parameters 0) of formula [c-1/2*(d*Sum((a-b)**2)),1] with a=Var(0,16,0), b=Var(1,16,1), c=Var(2,1,1), d=Var(3,1,2) ... OK
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [2024-04-13T20:12:02.827148+0000][2455][CRITICAL] module disabled: /usr/local/lib/python3.10/dist-packages/synthcity/plugins/generic/plugin_goggle.py
#   4%|▍         | 449/10000 [08:44<3:06:04,  1.17s/it]
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [2024-04-13T20:25:01.322092+0000][2455][CRITICAL] module disabled: /usr/local/lib/python3.10/dist-packages/synthcity/plugins/generic/plugin_goggle.py
#   4%|▍         | 449/10000 [08:23<2:58:25,  1.12s/it]
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [2024-04-13T20:37:38.717464+0000][2455][CRITICAL] module disabled: /usr/local/lib/python3.10/dist-packages/synthcity/plugins/generic/plugin_goggle.py
#   4%|▍         | 449/10000 [08:27<2:59:47,  1.13s/it]
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [2024-04-13T20:50:15.994034+0000][2455][CRITICAL] module disabled: /usr/local/lib/python3.10/dist-packages/synthcity/plugins/generic/plugin_goggle.py
#   4%|▍         | 449/10000 [08:23<2:58:39,  1.12s/it]
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
# [pyKeOps] Warning : at least one of the input tensors is not contiguous. Consider using contiguous data arrays to avoid unnecessary copies.
#
# Average Fit Time: 515.8385 seconds, Standard Deviation: 7.7971 seconds
# Average Generate Time: 0.1482 seconds, Standard Deviation: 0.0085 seconds

# %%
result_df
# Out:
#                                                    min       min       min  \
# stats.jensenshannon_dist.marginal             0.005621  0.005646  0.005763
# stats.chi_squared_test.marginal               0.551496  0.551944  0.551635
# stats.inv_kl_divergence.marginal              0.973562  0.973136  0.973179
# stats.ks_test.marginal                        0.923257  0.922581  0.922954
# stats.max_mean_discrepancy.joint              0.000225  0.000225  0.000225
# stats.wasserstein_dist.joint                  0.036354  0.036219  0.036277
# stats.prdc.precision                          0.960329  0.963259  0.963372
# stats.prdc.recall                             0.922011  0.920207  0.925166
# stats.prdc.density                            0.944055  0.959089  0.954085
# stats.prdc.coverage                           0.912994  0.916263  0.917390
# stats.survival_km_distance.optimism           0.000688  0.000357 -0.001234
# stats.survival_km_distance.abs_optimism       0.002304  0.003538  0.002892
# stats.survival_km_distance.sightedness        0.000000  0.000000  0.000000
# performance.linear_model.gt.c_index           0.568899  0.568899  0.568899
# performance.linear_model.gt.brier_score       0.208247  0.208247  0.208247
# performance.linear_model.syn_id.c_index       0.551514  0.551814  0.553050
# performance.linear_model.syn_id.brier_score   0.210347  0.210639  0.210521
# performance.linear_model.syn_ood.c_index      0.576001  0.573675  0.574779
# performance.linear_model.syn_ood.brier_score  0.208819  0.209425  0.209102
# performance.mlp.gt.c_index                    0.520378  0.520378  0.520378
# performance.mlp.gt.brier_score                0.219523  0.219523  0.219523
# performance.mlp.syn_id.c_index                0.497880  0.494939  0.498815
# performance.mlp.syn_id.brier_score            0.219010  0.220034  0.218974
# performance.mlp.syn_ood.c_index               0.500040  0.500231  0.500158
# performance.mlp.syn_ood.brier_score           0.219967  0.219661  0.219739
# performance.xgb.gt.c_index                    0.613365  0.613776  0.613345
# performance.xgb.gt.brier_score                0.195653  0.195389  0.195561
# performance.xgb.syn_id.c_index                0.576280  0.578428  0.583431
# performance.xgb.syn_id.brier_score            0.202098  0.201403  0.201050
# performance.xgb.syn_ood.c_index               0.594977  0.597780  0.611944
# performance.xgb.syn_ood.brier_score           0.200958  0.199263  0.196181
#
#                                                    min       min      Mean  \
# stats.jensenshannon_dist.marginal             0.005676  0.005699  0.005681
# stats.chi_squared_test.marginal               0.551796  0.551653  0.551705
# stats.inv_kl_divergence.marginal              0.972602  0.973610  0.973218
# stats.ks_test.marginal                        0.922785  0.923039  0.922923
# stats.max_mean_discrepancy.joint              0.000225  0.000225  0.000225
# stats.wasserstein_dist.joint                  0.036333  0.036517  0.036340
# stats.prdc.precision                          0.961569  0.964612  0.962628
# stats.prdc.recall                             0.923588  0.920884  0.922371
# stats.prdc.density                            0.962380  0.953364  0.954595
# stats.prdc.coverage                           0.917615  0.917052  0.916263
# stats.survival_km_distance.optimism          -0.000626 -0.000215 -0.000206
# stats.survival_km_distance.abs_optimism       0.001853  0.003260  0.002769
# stats.survival_km_distance.sightedness        0.000000  0.000000  0.000000
# performance.linear_model.gt.c_index           0.568899  0.568899  0.568899
# performance.linear_model.gt.brier_score       0.208247  0.208247  0.208247
# performance.linear_model.syn_id.c_index       0.555047  0.553451  0.552975
# performance.linear_model.syn_id.brier_score   0.210060  0.210090  0.210332
# performance.linear_model.syn_ood.c_index      0.577646  0.576135  0.575647
# performance.linear_model.syn_ood.brier_score  0.208661  0.208784  0.208958
# performance.mlp.gt.c_index                    0.520378  0.520378  0.520378
# performance.mlp.gt.brier_score                0.219523  0.219523  0.219523
# performance.mlp.syn_id.c_index                0.494214  0.496533  0.496476
# performance.mlp.syn_id.brier_score            0.222882  0.221857  0.220552
# performance.mlp.syn_ood.c_index               0.499860  0.500645  0.500187
# performance.mlp.syn_ood.brier_score           0.219957  0.219718  0.219808
# performance.xgb.gt.c_index                    0.612465  0.613834  0.613357
# performance.xgb.gt.brier_score                0.195665  0.195373  0.195528
# performance.xgb.syn_id.c_index                0.581067  0.581225  0.580086
# performance.xgb.syn_id.brier_score            0.201298  0.200380  0.201246
# performance.xgb.syn_ood.c_index               0.605913  0.602547  0.602632
# performance.xgb.syn_ood.brier_score           0.197288  0.196577  0.198053
#
#                                                  Std
# stats.jensenshannon_dist.marginal             0.0000
# stats.chi_squared_test.marginal               0.0002
# stats.inv_kl_divergence.marginal              0.0004
# stats.ks_test.marginal                        0.0002
# stats.max_mean_discrepancy.joint              0.0000
# stats.wasserstein_dist.joint                  0.0001
# stats.prdc.precision                          0.0015
# stats.prdc.recall                             0.0018
# stats.prdc.density                            0.0062
# stats.prdc.coverage                           0.0017
# stats.survival_km_distance.optimism           0.0007
# stats.survival_km_distance.abs_optimism       0.0006
# stats.survival_km_distance.sightedness        0.0000
# performance.linear_model.gt.c_index           0.0000
# performance.linear_model.gt.brier_score       0.0000
# performance.linear_model.syn_id.c_index       0.0013
# performance.linear_model.syn_id.brier_score   0.0002
# performance.linear_model.syn_ood.c_index      0.0013
# performance.linear_model.syn_ood.brier_score  0.0003
# performance.mlp.gt.c_index                    0.0000
# performance.mlp.gt.brier_score                0.0000
# performance.mlp.syn_id.c_index                0.0017
# performance.mlp.syn_id.brier_score            0.0016
# performance.mlp.syn_ood.c_index               0.0003
# performance.mlp.syn_ood.brier_score           0.0001
# performance.xgb.gt.c_index                    0.0005
# performance.xgb.gt.brier_score                0.0001
# performance.xgb.syn_id.c_index                0.0025
# performance.xgb.syn_id.brier_score            0.0006
# performance.xgb.syn_ood.c_index               0.0060
# performance.xgb.syn_ood.brier_score           0.0018

# %%
p_values_df
# Out:
#              x0            x7            x8            x9       x10  \
# 0  1.439564e-15  1.213733e-27  1.071006e-40  5.348859e-89  0.000065
# 1  1.890747e-16  1.529040e-26  2.475020e-40  4.367822e-90  0.000067
# 2  5.051416e-15  1.167503e-27  9.580590e-40  4.595969e-89  0.000109
# 3  2.135626e-16  1.081820e-27  7.002855e-39  1.185893e-89  0.000059
# 4  5.370450e-16  1.017775e-25  2.488546e-38  2.057553e-87  0.000055
#
#             x11            x12           x13        x1        x2        x3  \
# 0  4.627836e-20  9.643612e-201  1.093995e-65  0.916930  0.005193  0.082834
# 1  5.925394e-19  2.025548e-202  7.610552e-65  0.791561  0.305458  0.254180
# 2  2.043668e-19  2.089515e-200  5.640071e-65  0.045980  0.564496  0.805058
# 3  1.718059e-19  9.772604e-201  1.576937e-66  0.496314  0.869126  0.778002
# 4  4.838877e-19  8.397650e-202  8.502807e-65  0.511868  0.372019  0.958030
#
#          x4        x5        x6
# 0  0.989267  0.336832  0.790861
# 1  0.345976  0.001317  0.755085
# 2  0.187148  0.575016  0.453582
# 3  0.151704  0.381916  0.536724
# 4  0.124511  1.000000  0.316912

# %% [markdown]
# # FLCHAIN

# %%
dataset="flchain"

metrics_list = []
fit_times = []
generate_times = []
p_values_list = []

for i in range(5):
    df=pd.read_csv('/content/drive/MyDrive/Datasets/flchain.csv')
    df = df.drop('Unnamed: 0', axis=1)
    df = df[df['duration'] != 0]
    df=df.dropna()

    time = df['duration'].to_list()
    event = df['event'].to_list()

    time_event_encoded = sinusoidal_embedding(time, event, 4)
    X = df.drop(['duration', 'event'], axis=1)
    y = time_event_encoded

    syn_model = Plugins().get(plugin_name)

    # Measure the execution time of the fit function
    start = timer()
    syn_model.fit(X, cond=y)
    fit_time = timer() - start
    fit_times.append(fit_time)

    survival_df=df
    event_0_data = survival_df[survival_df['event'] == 0]['duration']
    event_1_data = survival_df[survival_df['event'] == 1]['duration']

    random_state = i + 1
    np.random.seed(random_state)

    sample_size_0 = len(event_0_data)
    sample_size_1= len(event_1_data)
    sample_event_0 = np.random.choice(event_0_data, size=sample_size_0)
    sample_event_1 = np.random.choice(event_1_data, size=sample_size_1)

    z=np.concatenate([sample_event_0,sample_event_1])
    x=np.zeros(len(sample_event_0))
    y=np.ones(len(sample_event_1))
    p=np.concatenate([x,y])

    time_event_gen_encoded=sinusoidal_embedding(z,p,4)

    # Measure the execution time of the generate function
    start = timer()
    X_gen = syn_model.generate(count=len(df), cond=np.array(time_event_gen_encoded)).dataframe()
    generate_time = timer() - start
    generate_times.append(generate_time)

    X_gen['duration'] = z
    X_gen['event'] = p
    X_gen = X_gen.sample(frac=1).reset_index(drop=True)

    # Save X_gen as a CSV file
    X_gen.to_csv(f"/content/drive/MyDrive/Nips/{dataset}_{plugin_name}_iteration_{i+1}.csv", index=False)

    loader1 = SurvivalAnalysisDataLoader(df, target_column="event", time_to_event_column="duration")
    loader2 = SurvivalAnalysisDataLoader(X_gen, target_column="event", time_to_event_column="duration")

    met_df = Metrics.evaluate(X_gt=loader1, X_syn=loader2, task_type='survival_analysis', metrics={
        'stats': ['jensenshannon_dist', 'chi_squared_test', 'feature_corr', 'inv_kl_divergence', 'ks_test',
                 'max_mean_discrepancy', 'wasserstein_dist', 'prdc', 'alpha_precision', 'survival_km_distance'],
        'performance': ['linear_model', 'mlp', 'xgb', 'feat_rank_distance']
    }, use_cache=False, random_state=random_state)

    met_df = met_df.iloc[:, 0]
    metrics_list.append(met_df)

    # Calculate p-values
    p_values_continuous, p_values_discrete = compare_distributions(df, X_gen)
    continuous_column_names = list(p_values_continuous.keys())
    discrete_column_names = list(p_values_discrete.keys())

    p_val = np.concatenate([list(p_values_continuous.values()), list(p_values_discrete.values())])
    p_values_list.append(p_val)

    workspace_dir = os.path.join(os.getcwd(), 'workspace')
    if os.path.exists(workspace_dir):
        shutil.rmtree(workspace_dir)

result_df = pd.concat(metrics_list, axis=1)

# Calculate the row-wise mean and standard deviation of the metrics
result_df['Mean'] = result_df.mean(axis=1)
result_df['Std'] = result_df.std(axis=1)
result_df['Std'] = result_df['Std'].round(4)

# Create DataFrame for p-values
p_values_df = pd.DataFrame(p_values_list, columns=continuous_column_names + discrete_column_names)

# Save result_df and p_values_df as CSV files
result_df.to_csv(f"/content/drive/MyDrive/Nips/{dataset}_{plugin_name}_result_df.csv")
p_values_df.to_csv(f"/content/drive/MyDrive/Nips/{dataset}_{plugin_name}_p_values_df.csv")

avg_fit_time = np.mean(fit_times)
avg_generate_time = np.mean(generate_times)
std_fit_time = np.std(fit_times)
std_generate_time = np.std(generate_times)

print(f"\nAverage Fit Time: {avg_fit_time:.4f} seconds, Standard Deviation: {std_fit_time:.4f} seconds")
print(f"Average Generate Time: {avg_generate_time:.4f} seconds, Standard Deviation: {std_generate_time:.4f} seconds")
